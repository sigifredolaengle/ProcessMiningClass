# %% [markdown]
# Process perspective
# ===================

# %%
# Listing 8 Reading and printing an event log with a dictionary

import datetime

f = open('purchasing.csv', 'r')

log = dict()

for line in f:
    line = line.strip()
    if len(line) == 0:
        continue
    parts = line.split(',')
    caseid = parts[0]
    task = parts[3]
    user = parts[4]
    timestamp = datetime.datetime.strptime(parts[1], '%Y-%m-%d %H:%M:%S')
    if caseid not in log:
        log[caseid] = []
    event = (task, user, timestamp)
    log[caseid].append(event)
    
f.close()

for caseid in sorted(log.keys()):
    log[caseid].sort(key = lambda event: event[-1])
    for (task, user, timestamp) in log[caseid]:
        print caseid, task, user, timestamp
# Out:
# WARNING: some intermediate output was truncated.
# WARNING: 9 intermediate output messages were discarded.
#  2011-03-06 21:05:00
# 448 Analyze Purchase Requisition Francis Odell 2011-03-07 18:24:00
# 448 Create Request for Quotation Requester Manager Francis Odell 2011-03-07 18:36:00
# 448 Analyze Request for Quotation Francois de Perrier 2011-03-08 18:34:00
# 448 Send Request for Quotation to Supplier Magdalena Predutta 2011-03-08 22:58:00
# 448 Create Quotation comparison Map Francois de Perrier 2011-03-08 23:13:00
# 448 Analyze Quotation comparison Map Tesca Lobes 2011-03-09 08:11:00
# 448 Choose best option Esmana Liubiata 2011-03-09 08:25:00
# 448 Settle conditions with supplier Magdalena Predutta 2011-03-09 18:36:00
# 448 Create Purchase Order Karel de Groot 2011-03-10 18:03:00
# 448 Confirm Purchase Order Kiu Kan 2011-03-10 22:28:00
# 448 Deliver Goods Services Esmeralda Clay 2011-03-13 20:27:00
# 448 Release Purchase Order Immanuel Karagianni 2011-03-14 11:53:00
# 448 Approve Purchase Order for payment Magdalena Predutta 2011-03-14 19:49:00
# 448 Send invoice Sean Manney 2011-03-15 01:48:00
# 448 Release Supplier's Invoice Karalda Nimwada 2011-03-15 16:14:00
# 448 Authorize Supplier's Invoice payment Karalda Nimwada 2011-03-15 16:21:00
# 448 Pay invoice Pedro Alvares 2011-03-15 16:54:00
# 449 Create Purchase Requisition Anne Olwada 2011-03-07 00:45:00
# 449 Analyze Purchase Requisition Heinz Gutschmidt 2011-03-07 14:41:00
# 449 Create Request for Quotation Requester Manager Francis Odell 2011-03-07 14:54:00
# 449 Analyze Request for Quotation Magdalena Predutta 2011-03-08 23:28:00
# 45 Create Purchase Requisition Nico Ojenbeer 2011-01-05 23:24:00
# 45 Analyze Purchase Requisition Heinz Gutschmidt 2011-01-06 11:30:00
# 45 Amend Purchase Requisition Clement Duchot 2011-01-06 23:26:00
# 45 Analyze Purchase Requisition Maris Freeman 2011-01-07 18:31:00
# 45 Create Request for Quotation Requester Manager Francis Odell 2011-01-07 18:48:00
# 45 Analyze Request for Quotation Karel de Groot 2011-01-08 04:11:00
# 45 Send Request for Quotation to Supplier Karel de Groot 2011-01-09 19:52:00
# 45 Create Quotation comparison Map Francois de Perrier 2011-01-10 18:25:00
# 45 Analyze Quotation comparison Map Miu Hanwan 2011-01-11 07:08:00
# 45 Choose best option Clement Duchot 2011-01-11 07:31:00
# 45 Settle conditions with supplier Magdalena Predutta 2011-01-11 11:00:00
# 45 Create Purchase Order Magdalena Predutta 2011-01-12 03:44:00
# 45 Confirm Purchase Order Kiu Kan 2011-01-12 12:12:00
# 45 Deliver Goods Services Carmen Finacse 2011-01-13 01:59:00
# 45 Release Purchase Order Esmana Liubiata 2011-01-14 11:15:00
# 45 Approve Purchase Order for payment Francois de Perrier 2011-01-15 08:48:00
# 45 Send invoice Kiu Kan 2011-01-17 03:34:00
# 45 Release Supplier's Invoice Pedro Alvares 2011-01-17 17:53:00
# 45 Authorize Supplier's Invoice payment Pedro Alvares 2011-01-17 17:56:00
# 45 Pay invoice Pedro Alvares 2011-01-17 18:30:00
# 450 Create Purchase Requisition Immanuel Karagianni 2011-03-07 01:14:00
# 450 Create Request for Quotation Requester Miu Hanwan 2011-03-07 06:51:00
# 450 Analyze Request for Quotation Magdalena Predutta 2011-03-29 18:39:00
# 450 Amend Request for Quotation Reques…
# 549 Release Supplier's Invoice Pedro Alvares 2011-04-05 18:59:00
# 549 Authorize Supplier's Invoice payment Karalda Nimwada 2011-04-05 19:58:00
# 549 Pay invoice Pedro Alvares 2011-04-05 20:57:00
# 55 Create Purchase Requisition Miu Hanwan 2011-01-07 19:26:00
# 55 Analyze Purchase Requisition Francis Odell 2011-01-08 10:54:00
# 55 Create Request for Quotation Requester Manager Francis Odell 2011-01-08 11:06:00
# 55 Analyze Request for Quotation Magdalena Predutta 2011-01-12 05:16:00
# 55 Send Request for Quotation to Supplier Magdalena Predutta 2011-01-12 18:37:00
# 55 Create Quotation comparison Map Karel de Groot 2011-01-13 04:09:00
# 55 Analyze Quotation comparison Map Christian Francois 2011-01-13 13:33:00
# 55 Choose best option Clement Duchot 2011-01-13 14:00:00
# 55 Settle conditions with supplier Karel de Groot 2011-01-14 01:08:00
# 55 Create Purchase Order Karel de Groot 2011-01-14 18:43:00
# 55 Confirm Purchase Order Esmeralda Clay 2011-01-16 23:44:00
# 55 Deliver Goods Services Carmen Finacse 2011-01-18 21:50:00
# 55 Release Purchase Order Anne Olwada 2011-01-20 20:05:00
# 55 Settle dispute with supplier Purchasing Agent Francois de Perrier 2011-01-21 01:29:00
# 55 Release Purchase Order Tesca Lobes 2011-01-21 18:49:00
# 55 Approve Purchase Order for payment Karel de Groot 2011-01-21 23:25:00
# 55 Send invoice Kiu Kan 2011-01-22 07:39:00
# 55 Release Supplier's Invoice Karalda Nimwada 2011-01-22 21:57:00
# 55 Authorize Supplier's Invoice payment Pedro Alvares 2011-01-22 22:02:00
# 55 Pay invoice Karalda Nimwada 2011-01-22 22:49:00
# 551 Create Purchase Requisition Anne Olwada 2011-03-20 09:36:00
# 551 Analyze Purchase Requisition Heinz Gutschmidt 2011-03-21 02:30:00
# 551 Create Request for Quotation Requester Manager Francis Odell 2011-03-21 02:41:00
# 551 Analyze Request for Quotation Magdalena Predutta 2011-03-24 21:01:00
# 551 Amend Request for Quotation Requester Clement Duchot 2011-03-24 22:18:00
# 551 Analyze Request for Quotation Karel de Groot 2011-03-26 18:12:00
# 551 Send Request for Quotation to Supplier Francois de Perrier 2011-03-27 00:48:00
# 551 Create Quotation comparison Map Francois de Perrier 2011-03-27 03:42:00
# 551 Analyze Quotation comparison Map Esmana Liubiata 2011-03-27 15:41:00
# 551 Choose best option Miu Hanwan 2011-03-27 15:51:00
# 551 Settle conditions with supplier Karel de Groot 2011-03-27 18:46:00
# 551 Create Purchase Order Karel de Groot 2011-03-28 01:44:00
# 551 Confirm Purchase Order Karen Clarens 2011-03-28 09:49:00
# 551 Deliver Goods Services Sean Manney 2011-03-28 22:17:00
# 551 Release Purchase Order Anna Kaufmann 2011-03-29 18:22:00
# 551 Approve Purchase Order for payment Karel de Groot 2011-03-29 22:53:00
# 551 Send invoice Esmeralda Clay 2011-03-31 10:20:00
# 551 Release Supplier's Invoice Pedro Alvares 2011-04-01 00:40:00
# 551 Authorize Supplier's Invoice payment Pedro Alvares 2011-04-01 00:42:00
# 551 Pay invoice Karalda Nimwada 2011-04-01 01:20:00
# 553 Create Purchase Requisition Anna Kaufmann 2011-03-20 21:07:00
# 553 Create Request for Quotation Requester Esmana Liubiata 2011-03-21 00:38:00
# 553 Analyze Request for Quotation Karel de Groot 2011-03-26 16:12:00
# 553 Send Request for Quotation to Supplier Francois de Perrier 2011-03-27 10:24:00
# 553 Create Quotation comparison Map Karel de Groot 2011-03-27 12:25:00
# 553 Analyze Quotation comparison Map Immanuel Karagianni 2011-03-28 00:33:00
# 553 Choose best option Kim Passa 2011-03-28 00:44:00
# 553 Settle conditions with supplier Karel de Groot 2011-03-28 04:50:00
# 553 Create Purchase Order Karel de Groot 2011-03-28 16:28:00
# 553 Confirm Purchase Order Esmeralda Clay 2011-03-31 03:30:00
# 553 Deliver Goods Services Karen Clarens 2011-04-02 21:30:00
# 553 Release Purchase Order Clement Duchot 2011-04-03 08:36:00
# 553 Approve Purchase Order for payment Francois de Perrier 2011-04-03 23:25:00
# 553 Send invoice Carmen Finacse 2011-04-04 22:18:00
# 553 Release Supplier's Invoice Pedro Alvares 2011-04-05 12:51:00
# 553 Authorize Supplier's Invoice payment Pedro Alvares 2011-04-05 12:58:00
# 553 Pay invoice Pedro Alvares 2011-04-05 13:46:00
# 556 Create Purchase Requisition Alberto Duport 2011-03-21 01:25:00
# 556 Analyze Purchase Requisition Maris Freeman 2011-03-22 02:13:00
# 556 Create Request for Quotation Requester Manager Francis Odell 2011-03-22 02:29:00
# 556 Analyze Request for Quotation Francois de Perrier 2011-03-30 10:06:00
# 556 Send Request for Quotation to Supplier Magdalena Predutta 2011-03-31 11:02:00
# 556 Create Quotation comparison Map Magdalena Predutta 2011-03-31 14:48:00
# 556 Analyze Quotation comparison Map Penn Osterwalder 2011-03-31 22:13:00
# 556 Choose best option Kim Passa 2011-03-31 22:35:00
# 556 Settle conditions with supplier Karel de Groot 2011-04-01 01:40:00
# 556 Create Purchase Order Francois de Perrier 2011-04-01 19:11:00
# 556 Confirm Purchase Order Sean Manney 2011-04-02 12:44:00
# 556 Deliver Goods Services Karen Clarens 2011-04-03 01:58:00
# 556 Release Purchase Order Penn Osterwalder 2011-04-03 19:26:00
# 556 Approve Purchase Order for payment Francois de Perrier 2011-04-04 10:11:00
# 556 Send invoice Carmen Finacse 2011-04-04 21:45:00
# 556 Release Supplier's Invoice Pedro Alvares 2011-04-05 12:13:00
# 556 Authorize Supplier's Invoice payment Karalda Nimwada 2011-04-05 12:17:00
# 556 Pay invoice Pedro Alvares 2011-04-05 13:03:00
# 559 Create Purchase Requisition Miu Hanwan 2011-03-21 05:52:00
# 559 Create Request for Quotation Requester Anna Kaufmann 2011-03-21 13:43:00
# 559 Analyze Request for Quotation Magdalena Predutta 2011-04-28 00:30:00
# 559 Amend Request for Quotation Requester Anne Olwada 2011-04-28 01:30:00
# 559 Analyze Request for Quotation Francois de Perrier 2011-05-28 09:03:00
# 559 Amend Request for Quotation Requester Anne Olwada 2011-05-28 10:16:00
# 559 Analyze Request for Quotation Karel de Groot 2011-05-30 17:03:00
# 559 Amend Request for Quotation Requester Elvira Lores 2011-05-30 18:22:00
# 559 Analyze Request for Quotation Magdalena Predutta 2011-06-11 21:21:00
# 559 Send Request for Quotation to Supplier Francois de Perrier 2011-06-12 10:54:00
# 559 Create Quotation comparison Map Francois de Perrier 2011-06-12 22:41:00
# 559 Analyze Quotation comparison Map Elvira Lores 2011-06-13 10:55:00
# 559 Choose best option Kim Passa 2011-06-13 11:13:00
# 559 Settle conditions with supplier Karel de Groot 2011-06-13 14:01:00
# 559 Create Purchase Order Magdalena Predutta 2011-06-14 05:10:00
# 559 Confirm Purchase Order Esmeralda Clay 2011-06-15 13:55:00
# 559 Deliver Goods Services Sean Manney 2011-06-17 00:57:00
# 559 Release Purchase Order Nico Ojenbeer 2011-06-18 00:02:00
# 559 Approve Purchase Order for payment Francois de Perrier 2011-06-18 12:46:00
# 559 Send invoice Esmeralda Clay 2011-06-20 09:18:00
# 559 Release Supplier's Invoice Pedro Alvares 2011-06-20 23:39:00
# 559 Authorize Supplier's Invoice payment Karalda Nimwada 2011-06-20 23:41:00
# 559 Pay invoice Karalda Nimwada 2011-06-21 00:30:00
# 56 Create Purchase Requisition Tesca Lobes 2011-01-07 20:35:00
# 56 Analyze Purchase Requisition Maris Freeman 2011-01-08 18:32:00
# 56 Create Request for Quotation Requester Manager Heinz Gutschmidt 2011-01-08 18:43:00
# 56 Analyze Request for Quotation Francois de Perrier 2011-01-09 02:02:00
# 56 Send Request for Quotation to Supplier Magdalena Predutta 2011-01-09 17:14:00
# 56 Create Quotation comparison Map Karel de Groot 2011-01-10 17:49:00
# 56 Analyze Quotation comparison Map Christian Francois 2011-01-11 05:26:00
# 56 Choose best option Kim Passa 2011-01-11 05:48:00
# 56 Settle conditions with supplier Karel de Groot 2011-01-11 19:51:00
# 56 Create Purchase Order Karel de Groot 2011-01-12 02:58:00
# 56 Confirm Purchase Order Sean Manney 2011-01-13 01:22:00
# 56 Deliver Goods Services Karen Clarens 2011-01-14 22:42:00
# 56 Release Purchase Order Penn Osterwalder 2011-01-16 14:23:00
# 56 Approve Purchase Order for payment Karel de Groot 2011-01-17 00:07:00
# 56 Send invoice Esmeralda Clay 2011-01-17 06:53:00
# 56 Release Supplier's Invoice Pedro Alvares 2011-01-17 21:17:00
# 56 Settle dispute with supplier Financial Manager Pedro Alvares 2011-01-17 21:58:00
# 56 Authorize Supplier's Invoice payment Pedro Alvares 2011-01-17 22:32:00
# 56 Pay invoice Karalda Nimwada 2011-01-17 22:37:00
# 560 Create Purchase Requisition Kim Passa 2011-03-21 06:35:00
# 560 Analyze Purchase Requisition Maris Freeman 2011-03-22 05:41:00
# 560 Create Request for Quotation Requester Manager Francis Odell 2011-03-22 05:55:00
# 560 Analyze Request for Quotation Francois de Perrier 2011-03-27 09:43:00
# 560 Send Request for Quotation to Supplier Francois de Perrier 2011-03-27 21:49:00
# 560 Create Quotation comparison Map Francois de Perrier 2011-03-28 01:03:00
# 560 Analyze Quotation comparison Map Christian Francois 2011-03-28 10:17:00
# 560 Choose best option Miu Hanwan 2011-03-28 10:48:00
# 560 Settle conditions with supplier Magdalena Predutta 2011-03-28 22:22:00
# 560 Create Purchase Order Francois de Perrier 2011-03-29 15:25:00
# 560 Confirm Purchase Order Kiu Kan 2011-03-30 20:02:00
# 560 Deliver Goods Services Karen Clarens 2011-03-31 08:57:00
# 560 Release Purchase Order Immanuel Karagianni 2011-04-01 03:52:00
# 560 Approve Purchase Order for payment Magdalena Predutta 2011-04-01 11:57:00
# 560 Send invoice Karen Clarens 2011-04-05 01:49:00
# 560 Release Supplier's Invoice Pedro Alvares 2011-04-05 16:14:00
# 560 Authorize Supplier's Invoice payment Pedro Alvares 2011-04-05 16:18:00
# 560 Pay invoice Pedro Alvares 2011-04-05 17:24:00
# 563 Create Purchase Requisition Kim Passa 2011-03-21 18:41:00
# 563 Analyze Purchase Requisition Heinz Gutschmidt 2011-03-22 12:46:00
# 563 Create Request for Quotation Requester Manager Francis Odell 2011-03-22 12:57:00
# 563 Analyze Request for Quotation Karel de Groot 2011-03-26 14:46:00
# 563 Send Request for Quotation to Supplier Karel de Groot 2011-03-27 09:09:00
# 563 Create Quotation comparison Map Karel de Groot 2011-03-27 10:24:00
# 563 Analyze Quotation comparison Map Immanuel Karagianni 2011-03-27 19:31:00
# 563 Choose best option Immanuel Karagianni 2011-03-27 19:50:00
# 563 Settle conditions with supplier Magdalena Predutta 2011-03-27 22:36:00
# 563 Create Purchase Order Magdalena Predutta 2011-03-28 07:57:00
# 563 Confirm Purchase Order Carmen Finacse 2011-03-31 13:47:00
# 563 Deliver Goods Services Sean Manney 2011-04-02 19:59:00
# 563 Release Purchase Order Kim Passa 2011-04-05 01:37:00
# 563 Approve Purchase Order for payment Francois de Perrier 2011-04-05 04:48:00
# 563 Send invoice Karen Clarens 2011-04-05 11:40:00
# 563 Release Supplier's Invoice Karalda Nimwada 2011-04-06 02:00:00
# 563 Settle dispute with supplier Financial Manager Pedro Alvares 2011-04-06 02:25:00
# 563 Authorize Supplier's Invoice payment Pedro Alvares 2011-04-06 02:57:00
# 563 Pay invoice Pedro Alvares 2011-04-06 03:38:00
# 564 Create Purchase Requisition Immanuel Karagianni 2011-03-21 20:13:00
# 564 Analyze Purchase Requisition Heinz Gutschmidt 2011-03-22 07:30:00
# 564 Create Request for Quotation Requester Manager Heinz Gutschmidt 2011-03-22 07:40:00
# 564 Analyze Request for Quotation Karel de Groot 2011-03-23 00:44:00
# 564 Send Request for Quotation to Supplier Karel de Groot 2011-03-23 18:48:00
# 564 Create Quotation comparison Map Magdalena Predutta 2011-03-24 12:57:00
# 564 Analyze Quotation comparison Map Fjodor Kowalski 2011-03-24 21:30:00
# 564 Choose best option Christian Francois 2011-03-24 22:02:00
# 564 Settle conditions with supplier Magdalena Predutta 2011-03-26 08:31:00
# 564 Create Purchase Order Francois de Perrier 2011-03-27 03:33:00
# 564 Confirm Purchase Order Kiu Kan 2011-03-30 19:39:00
# 564 Deliver Goods Services Esmeralda Clay 2011-04-02 11:56:00
# 564 Release Purchase Order Clement Duchot 2011-04-03 05:50:00
# 564 Settle dispute with supplier Purchasing Agent Francois de Perrier 2011-04-03 13:12:00
# 564 Release Purchase Order Anne Olwada 2011-04-04 05:45:00
# 564 Approve Purchase Order for payment Karel de Groot 2011-04-04 22:33:00
# 564 Send invoice Sean Manney 2011-04-05 04:32:00
# 564 Release Supplier's Invoice Pedro Alvares 2011-04-05 19:38:00
# 564 Authorize Supplier's Invoice payment Pedro Alvares 2011-04-05 20:09:00
# 564 Pay invoice Pedro Alvares 2011-04-05 21:21:00
# 565 Create Purchase Requisition Miu Hanwan 2011-03-21 20:21:00
# 565 Create Request for Quotation Requester Fjodor Kowalski 2011-03-22 01:51:00
# 565 Analyze Request for Quotation Magdalena Predutta 2011-03-23 02:24:00
# 565 Send Request for Quotation to Supplier Magdalena Predutta 2011-03-23 19:38:00
# 565 Create Quotation comparison Map Francois de Perrier 2011-03-24 20:55:00
# 565 Analyze Quotation comparison Map Clement Duchot 2011-03-25 06:08:00
# 565 Choose best option Miu Hanwan 2011-03-25 06:26:00
# 565 Settle conditions with supplier Karel de Groot 2011-03-25 09:05:00
# 565 Create Purchase Order Magdalena Predutta 2011-03-26 08:25:00
# 565 Confirm Purchase Order Karen Clarens 2011-03-27 00:55:00
# 565 Deliver Goods Services Esmeralda Clay 2011-03-31 04:06:00
# 565 Release Purchase Order Kim Passa 2011-03-31 17:32:00
# 565 Approve Purchase Order for payment Karel de Groot 2011-03-31 23:30:00
# 565 Send invoice Carmen Finacse 2011-04-04 23:09:00
# 565 Release Supplier's Invoice Karalda Nimwada 2011-04-05 13:34:00
# 565 Authorize Supplier's Invoice payment Karalda Nimwada 2011-04-05 13:45:00
# 565 Pay invoice Karalda Nimwada 2011-04-05 13:56:00
# 57 Create Purchase Requisition Anne Olwada 2011-01-08 02:37:00
# 57 Analyze Purchase Requisition Maris Freeman 2011-01-08 17:41:00
# 57 Create Request for Quotation Requester Manager Maris Freeman 2011-01-08 17:53:00
# 57 Analyze Request for Quotation Francois de Perrier 2011-01-09 06:38:00
# 572 Create Purchase Requisition Anna Kaufmann 2011-03-22 12:33:00
# 572 Analyze Purchase Requisition Heinz Gutschmidt 2011-03-23 04:27:00
# 572 Create Request for Quotation Requester Manager Francis Odell 2011-03-23 04:37:00
# 572 Analyze Request for Quotation Francois de Perrier 2011-03-24 20:46:00
# 573 Create Purchase Requisition Kim Passa 2011-03-22 12:49:00
# 573 Analyze Purchase Requisition Francis Odell 2011-03-23 12:07:00
# 573 Create Request for Quotation Requester Manager Francis Odell 2011-03-23 12:16:00
# 573 Analyze Request for Quotation Magdalena Predutta 2011-03-27 17:12:00
# 573 Amend Request for Quotation Requester Anne Olwada 2011-03-27 18:23:00
# 573 Analyze Request for Quotation Francois de Perrier 2011-03-27 19:55:00
# 573 Send Request for Quotation to Supplier Magdalena Predutta 2011-03-27 22:03:00
# 573 Create Quotation comparison Map Karel de Groot 2011-03-28 01:52:00
# 573 Analyze Quotation comparison Map Kim Passa 2011-03-28 11:23:00
# 573 Choose best option Elvira Lores 2011-03-28 11:49:00
# 573 Settle conditions with supplier Magdalena Predutta 2011-03-28 16:32:00
# 573 Create Purchase Order Francois de Perrier 2011-03-29 03:12:00
# 573 Confirm Purchase Order Carmen Finacse 2011-03-29 16:54:00
# 573 Deliver Goods Services Sean Manney 2011-04-01 00:23:00
# 573 Release Purchase Order Christian Francois 2011-04-02 20:08:00
# 573 Approve Purchase Order for payment Karel de Groot 2011-04-03 04:59:00
# 573 Send invoice Carmen Finacse 2011-04-05 00:19:00
# 573 Release Supplier's Invoice Karalda Nimwada 2011-04-05 14:51:00
# 573 Authorize Supplier's Invoice payment Karalda Nimwada 2011-04-05 14:55:00
# 573 Pay invoice Pedro Alvares 2011-04-05 15:52:00
# 575 Create Purchase Requisition Alberto Duport 2011-03-22 14:42:00
# 575 Analyze Purchase Requisition Heinz Gutschmidt 2011-03-23 12:07:00
# 575 Create Request for Quotation Requester Manager Maris Freeman 2011-03-23 12:20:00
# 575 Analyze Request for Quotation Francois de Perrier 2011-03-26 19:53:00
# 575 Amend Request for Quotation Requester Fjodor Kowalski 2011-03-26 21:04:00
# 575 Analyze Request for Quotation Francois de Perrier 2011-03-27 18:51:00
# 575 Send Request for Quotation to Supplier Francois de Perrier 2011-03-27 21:06:00
# 575 Create Quotation comparison Map Karel de Groot 2011-03-27 23:27:00
# 575 Analyze Quotation comparison Map Kim Passa 2011-03-28 08:15:00
# 575 Choose best option Tesca Lobes 2011-03-28 08:44:00
# 575 Settle conditions with supplier Francois de Perrier 2011-03-28 16:38:00
# 575 Create Purchase Order Francois de Perrier 2011-03-29 03:19:00
# 575 Confirm Purchase Order Esmeralda Clay 2011-03-31 02:42:00
# 575 Deliver Goods Services Esmeralda Clay 2011-03-31 10:20:00
# 575 Release Purchase Order Nico Ojenbeer 2011-04-01 09:27:00
# 575 Approve Purchase Order for payment Francois de Perrier 2011-04-01 19:30:00
# 575 Send invoice Karen Clarens 2011-04-05 04:12:00
# 575 Release Supplier's Invoice Pedro Alvares 2011-04-05 18:31:00
# 575 Settle dispute with supplier Financial Manager Pedro Alvares 2011-04-05 19:15:00
# 575 Authorize Supplier's Invoice payment Pedro Alvares 2011-04-05 20:09:00
# 575 Pay invoice Karalda Nimwada 2011-04-05 21:10:00
# 58 Create Purchase Requisition Alberto Duport 2011-01-08 03:01:00
# 58 Analyze Purchase Requisition Francis Odell 2011-01-09 01:08:00
# 58 Create Request for Quotation Requester Manager Maris Freeman 2011-01-09 01:19:00
# 58 Analyze Request for Quotation Karel de Groot 2011-01-09 03:31:00
# 58 Amend Request for Quotation Requester Clement Duchot 2011-01-09 04:58:00
# 58 Analyze Request for Quotation Karel de Groot 2011-01-10 16:51:00
# 58 Amend Request for Quotation Requester Nico Ojenbeer 2011-01-10 18:13:00
# 58 Analyze Request for Quotation Magdalena Predutta 2011-01-12 03:21:00
# 58 Send Request for Quotation to Supplier Francois de Perrier 2011-01-12 22:18:00
# 58 Create Quotation comparison Map Magdalena Predutta 2011-01-13 00:34:00
# 58 Analyze Quotation comparison Map Penn Osterwalder 2011-01-13 09:41:00
# 58 Choose best option Anne Olwada 2011-01-13 10:11:00
# 58 Settle conditions with supplier Magdalena Predutta 2011-01-13 21:44:00
# 58 Create Purchase Order Magdalena Predutta 2011-01-14 10:21:00
# 58 Confirm Purchase Order Carmen Finacse 2011-01-18 17:06:00
# 58 Deliver Goods Services Esmeralda Clay 2011-01-19 11:15:00
# 58 Release Purchase Order Tesca Lobes 2011-01-19 22:30:00
# 58 Settle dispute with supplier Purchasing Agent Francois de Perrier 2011-01-20 04:56:00
# 58 Release Purchase Order Fjodor Kowalski 2011-01-20 21:35:00
# 58 Approve Purchase Order for payment Francois de Perrier 2011-01-22 09:18:00
# 58 Send invoice Karen Clarens 2011-01-22 23:13:00
# 58 Release Supplier's Invoice Karalda Nimwada 2011-01-23 13:20:00
# 58 Authorize Supplier's Invoice payment Karalda Nimwada 2011-01-23 13:26:00
# 58 Pay invoice Pedro Alvares 2011-01-23 13:48:00
# 582 Create Purchase Requisition Alberto Duport 2011-03-23 09:03:00
# 582 Analyze Purchase Requisition Francis Odell 2011-03-24 06:28:00
# 582 Create Request for Quotation Requester Manager Heinz Gutschmidt 2011-03-24 06:43:00
# 582 Analyze Request for Quotation Karel de Groot 2011-03-29 21:17:00
# 582 Amend Request for Quotation Requester Alberto Duport 2011-03-29 22:39:00
# 582 Analyze Request for Quotation Magdalena Predutta 2011-04-01 02:49:00
# 582 Amend Request for Quotation Requester Clement Duchot 2011-04-01 03:54:00
# 582 Analyze Request for Quotation Karel de Groot 2011-04-05 04:16:00
# 59 Create Purchase Requisition Nico Ojenbeer 2011-01-08 10:44:00
# 59 Create Request for Quotation Requester Christian Francois 2011-01-08 11:52:00
# 59 Analyze Request for Quotation Magdalena Predutta 2011-01-08 14:53:00
# 59 Amend Request for Quotation Requester Tesca Lobes 2011-01-08 15:56:00
# 59 Analyze Request for Quotation Francois de Perrier 2011-01-09 01:50:00
# 59 Amend Request for Quotation Requester Fjodor Kowalski 2011-01-09 02:52:00
# 59 Analyze Request for Quotation Francois de Perrier 2011-01-09 06:47:00
# 59 Amend Request for Quotation Requester Manager Maris Freeman 2011-01-09 23:03:00
# 59 Analyze Request for Quotation Magdalena Predutta 2011-01-10 19:36:00
# 59 Send Request for Quotation to Supplier Magdalena Predutta 2011-01-11 23:06:00
# 59 Create Quotation comparison Map Magdalena Predutta 2011-01-12 00:06:00
# 59 Analyze Quotation comparison Map Clement Duchot 2011-01-12 08:54:00
# 59 Choose best option Fjodor Kowalski 2011-01-12 09:04:00
# 59 Settle conditions with supplier Magdalena Predutta 2011-01-12 13:26:00
# 59 Create Purchase Order Francois de Perrier 2011-01-12 22:08:00
# 59 Confirm Purchase Order Karen Clarens 2011-01-13 07:41:00
# 59 Deliver Goods Services Esmeralda Clay 2011-01-14 23:18:00
# 59 Release Purchase Order Miu Hanwan 2011-01-17 06:54:00
# 59 Approve Purchase Order for payment Magdalena Predutta 2011-01-17 17:33:00
# 59 Send invoice Carmen Finacse 2011-01-18 17:45:00
# 59 Release Supplier's Invoice Pedro Alvares 2011-01-19 08:00:00
# 59 Authorize Supplier's Invoice payment Pedro Alvares 2011-01-19 08:03:00
# 59 Pay invoice Pedro Alvares 2011-01-19 08:31:00
# 595 Create Purchase Requisition Miu Hanwan 2011-03-25 12:07:00
# 595 Analyze Purchase Requisition Francis Odell 2011-03-25 23:13:00
# 595 Create Request for Quotation Requester Manager Francis Odell 2011-03-25 23:23:00
# 595 Analyze Request for Quotation Magdalena Predutta 2011-03-29 16:54:00
# 595 Send Request for Quotation to Supplier Francois de Perrier 2011-03-30 05:37:00
# 595 Create Quotation comparison Map Francois de Perrier 2011-03-30 06:27:00
# 595 Analyze Quotation comparison Map Tesca Lobes 2011-03-30 16:34:00
# 595 Choose best option Christian Francois 2011-03-30 16:56:00
# 595 Settle conditions with supplier Magdalena Predutta 2011-03-30 21:43:00
# 595 Create Purchase Order Magdalena Predutta 2011-03-31 14:36:00
# 595 Confirm Purchase Order Kiu Kan 2011-04-03 16:27:00
# 595 Deliver Goods Services Sean Manney 2011-04-04 18:45:00
# 595 Release Purchase Order Tesca Lobes 2011-04-05 11:57:00
# 595 Approve Purchase Order for payment Magdalena Predutta 2011-04-05 22:28:00
# 595 Send invoice Carmen Finacse 2011-04-06 19:20:00
# 595 Release Supplier's Invoice Pedro Alvares 2011-04-07 09:36:00
# 595 Authorize Supplier's Invoice payment Karalda Nimwada 2011-04-07 09:42:00
# 595 Pay invoice Pedro Alvares 2011-04-07 10:05:00
# 596 Create Purchase Requisition Elvira Lores 2011-03-25 19:01:00
# 596 Analyze Purchase Requisition Francis Odell 2011-03-26 05:20:00
# 596 Create Request for Quotation Requester Manager Heinz Gutschmidt 2011-03-26 05:29:00
# 596 Analyze Request for Quotation Karel de Groot 2011-03-26 15:18:00
# 596 Send Request for Quotation to Supplier Francois de Perrier 2011-03-26 19:39:00
# 596 Create Quotation comparison Map Francois de Perrier 2011-03-26 20:12:00
# 596 Analyze Quotation comparison Map Nico Ojenbeer 2011-03-27 07:49:00
# 596 Choose best option Anna Kaufmann 2011-03-27 08:15:00
# 596 Settle conditions with supplier Francois de Perrier 2011-03-27 12:22:00
# 596 Create Purchase Order Francois de Perrier 2011-03-27 20:27:00
# 596 Confirm Purchase Order Sean Manney 2011-03-29 10:43:00
# 596 Deliver Goods Services Kiu Kan 2011-03-30 06:03:00
# 596 Release Purchase Order Penn Osterwalder 2011-03-31 02:53:00
# 596 Approve Purchase Order for payment Magdalena Predutta 2011-03-31 12:06:00
# 596 Send invoice Kiu Kan 2011-04-03 16:22:00
# 596 Release Supplier's Invoice Karalda Nimwada 2011-04-04 06:40:00
# 596 Authorize Supplier's Invoice payment Karalda Nimwada 2011-04-04 06:45:00
# 596 Pay invoice Pedro Alvares 2011-04-04 07:05:00
# 598 Create Purchase Requisition Nico Ojenbeer 2011-03-25 23:04:00
# 598 Analyze Purchase Requisition Heinz Gutschmidt 2011-03-26 15:24:00
# 598 Create Request for Quotation Requester Manager Francis Odell 2011-03-26 15:35:00
# 598 Analyze Request for Quotation Francois de Perrier 2011-03-30 04:53:00
# 6 Create Purchase Requisition Christian Francois 2011-01-01 11:20:00
# 6 Create Request for Quotation Requester Alberto Duport 2011-01-01 17:32:00
# 6 Analyze Request for Quotation Magdalena Predutta 2011-01-01 18:39:00
# 6 Amend Request for Quotation Requester Penn Osterwalder 2011-01-01 19:47:00
# 6 Analyze Request for Quotation Francois de Perrier 2011-01-01 20:55:00
# 6 Amend Request for Quotation Requester Anne Olwada 2011-01-01 22:13:00
# 6 Analyze Request for Quotation Karel de Groot 2011-01-01 23:24:00
# 6 Send Request for Quotation to Supplier Francois de Perrier 2011-01-02 09:51:00
# 6 Create Quotation comparison Map Francois de Perrier 2011-01-02 10:27:00
# 6 Analyze Quotation comparison Map Penn Osterwalder 2011-01-02 21:44:00
# 6 Choose best option Tesca Lobes 2011-01-02 22:01:00
# 6 Settle conditions with supplier Francois de Perrier 2011-01-03 00:25:00
# 6 Create Purchase Order Karel de Groot 2011-01-03 14:57:00
# 6 Confirm Purchase Order Karen Clarens 2011-01-03 18:55:00
# 6 Deliver Goods Services Karen Clarens 2011-01-04 05:08:00
# 6 Release Purchase Order Nico Ojenbeer 2011-01-05 10:27:00
# 6 Approve Purchase Order for payment Karel de Groot 2011-01-05 17:09:00
# 6 Send invoice Esmeralda Clay 2011-01-05 22:56:00
# 6 Release Supplier's Invoice Karalda Nimwada 2011-01-06 13:12:00
# 6 Authorize Supplier's Invoice payment Karalda Nimwada 2011-01-06 13:19:00
# 6 Pay invoice Karalda Nimwada 2011-01-06 13:43:00
# 606 Create Purchase Requisition Tesca Lobes 2011-03-26 14:52:00
# 606 Analyze Purchase Requisition Francis Odell 2011-03-27 00:59:00
# 606 Create Request for Quotation Requester Manager Heinz Gutschmidt 2011-03-27 03:12:00
# 606 Analyze Request for Quotation Magdalena Predutta 2011-03-27 16:06:00
# 606 Send Request for Quotation to Supplier Francois de Perrier 2011-03-27 19:31:00
# 606 Create Quotation comparison Map Francois de Perrier 2011-03-27 22:20:00
# 606 Analyze Quotation comparison Map Elvira Lores 2011-03-28 07:11:00
# 606 Choose best option Alberto Duport 2011-03-28 07:28:00
# 606 Settle conditions with supplier Francois de Perrier 2011-03-28 22:00:00
# 606 Create Purchase Order Magdalena Predutta 2011-03-29 16:41:00
# 606 Confirm Purchase Order Carmen Finacse 2011-04-04 22:18:00
# 606 Deliver Goods Services Sean Manney 2011-04-05 05:22:00
# 606 Release Purchase Order Tesca Lobes 2011-04-06 21:26:00
# 606 Approve Purchase Order for payment Magdalena Predutta 2011-04-07 10:25:00
# 606 Send invoice Esmeralda Clay 2011-04-08 01:36:00
# 606 Release Supplier's Invoice Pedro Alvares 2011-04-08 15:51:00
# 606 Authorize Supplier's Invoice payment Karalda Nimwada 2011-04-08 15:55:00
# 606 Pay invoice Pedro Alvares 2011-04-08 15:58:00
# 61 Create Purchase Requisition Esmana Liubiata 2011-01-08 13:50:00
# 61 Create Request for Quotation Requester Esmana Liubiata 2011-01-08 18:14:00
# 61 Analyze Request for Quotation Magdalena Predutta 2011-01-10 06:02:00
# 61 Amend Request for Quotation Requester Miu Hanwan 2011-01-10 07:02:00
# 61 Analyze Request for Quotation Magdalena Predutta 2011-01-12 06:02:00
# 61 Amend Request for Quotation Requester Manager Heinz Gutschmidt 2011-01-12 22:27:00
# 61 Analyze Request for Quotation Karel de Groot 2011-01-14 00:50:00
# 61 Amend Request for Quotation Requester Christian Francois 2011-01-14 01:55:00
# 61 Analyze Request for Quotation Francois de Perrier 2011-01-17 00:58:00
# 61 Send Request for Quotation to Supplier Magdalena Predutta 2011-01-17 05:17:00
# 61 Create Quotation comparison Map Francois de Perrier 2011-01-17 06:02:00
# 61 Analyze Quotation comparison Map Esmana Liubiata 2011-01-17 13:45:00
# 61 Choose best option Immanuel Karagianni 2011-01-17 14:02:00
# 61 Settle conditions with supplier Magdalena Predutta 2011-01-17 17:44:00
# 61 Create Purchase Order Magdalena Predutta 2011-01-18 03:01:00
# 61 Confirm Purchase Order Kiu Kan 2011-01-18 11:10:00
# 61 Deliver Goods Services Karen Clarens 2011-01-19 12:30:00
# 61 Release Purchase Order Miu Hanwan 2011-01-21 05:29:00
# 61 Approve Purchase Order for payment Karel de Groot 2011-01-21 19:02:00
# 61 Send invoice Kiu Kan 2011-01-22 07:39:00
# 61 Release Supplier's Invoice Pedro Alvares 2011-01-22 22:10:00
# 61 Authorize Supplier's Invoice payment Pedro Alvares 2011-01-22 22:13:00
# 61 Pay invoice Karalda Nimwada 2011-01-22 22:42:00
# 611 Create Purchase Requisition Elvira Lores 2011-03-27 11:49:00
# 611 Create Request for Quotation Requester Anna Kaufmann 2011-03-27 13:18:00
# 611 Analyze Request for Quotation Magdalena Predutta 2011-03-29 19:07:00
# 611 Send Request for Quotation to Supplier Karel de Groot 2011-03-29 22:35:00
# 611 Create Quotation comparison Map Magdalena Predutta 2011-03-30 02:36:00
# 611 Analyze Quotation comparison Map Fjodor Kowalski 2011-03-30 15:38:00
# 611 Choose best option Elvira Lores 2011-03-30 16:08:00
# 611 Settle conditions with supplier Francois de Perrier 2011-03-30 21:28:00
# 611 Create Purchase Order Magdalena Predutta 2011-03-31 11:46:00
# 611 Confirm Purchase Order Carmen Finacse 2011-04-01 06:25:00
# 611 Deliver Goods Services Carmen Finacse 2011-04-03 06:08:00
# 611 Release Purchase Order Tesca Lobes 2011-04-05 05:24:00
# 611 Approve Purchase Order for payment Karel de Groot 2011-04-06 04:23:00
# 611 Send invoice Sean Manney 2011-04-06 14:15:00
# 611 Release Supplier's Invoice Pedro Alvares 2011-04-07 04:37:00
# 611 Authorize Supplier's Invoice payment Pedro Alvares 2011-04-07 04:41:00
# 611 Pay invoice Karalda Nimwada 2011-04-07 05:24:00
# 612 Create Purchase Requisition Esmana Liubiata 2011-03-27 21:04:00
# 612 Analyze Purchase Requisition Maris Freeman 2011-03-28 10:58:00
# 612 Create Request for Quotation Requester Manager Francis Odell 2011-03-28 11:10:00
# 612 Analyze Request for Quotation Francois de Perrier 2011-03-28 13:34:00
# 612 Amend Request for Quotation Requester Christian Francois 2011-03-28 14:38:00
# 612 Analyze Request for Quotation Magdalena Predutta 2011-03-29 17:50:00
# 612 Amend Request for Quotation Requester Nico Ojenbeer 2011-03-29 18:54:00
# 612 Analyze Request for Quotation Francois de Perrier 2011-04-01 00:00:00
# 613 Create Purchase Requisition Fjodor Kowalski 2011-03-28 07:59:00
# 613 Analyze Purchase Requisition Maris Freeman 2011-03-29 06:00:00
# 615 Create Purchase Requisition Elvira Lores 2011-03-28 14:07:00
# 615 Create Request for Quotation Requester Tesca Lobes 2011-03-28 22:40:00
# 615 Analyze Request for Quotation Magdalena Predutta 2011-03-30 01:51:00
# 615 Send Request for Quotation to Supplier Francois de Perrier 2011-03-30 21:04:00
# 615 Create Quotation comparison Map Magdalena Predutta 2011-03-31 12:07:00
# 615 Analyze Quotation comparison Map Anne Olwada 2011-03-31 21:16:00
# 615 Choose best option Immanuel Karagianni 2011-03-31 21:42:00
# 615 Settle conditions with supplier Francois de Perrier 2011-04-01 00:41:00
# 615 Create Purchase Order Magdalena Predutta 2011-04-01 11:32:00
# 615 Confirm Purchase Order Karen Clarens 2011-04-05 03:13:00
# 615 Deliver Goods Services Karen Clarens 2011-04-06 13:18:00
# 615 Release Purchase Order Christian Francois 2011-04-08 04:48:00
# 615 Approve Purchase Order for payment Magdalena Predutta 2011-04-08 22:55:00
# 615 Send invoice Kiu Kan 2011-04-12 16:30:00
# 615 Release Supplier's Invoice Pedro Alvares 2011-04-13 06:47:00
# 615 Authorize Supplier's Invoice payment Karalda Nimwada 2011-04-13 06:54:00
# 615 Pay invoice Pedro Alvares 2011-04-13 07:05:00
# 616 Create Purchase Requisition Anne Olwada 2011-03-28 15:48:00
# 616 Create Request for Quotation Requester Anne Olwada 2011-03-28 23:05:00
# 616 Analyze Request for Quotation Francois de Perrier 2011-03-31 20:37:00
# 616 Send Request for Quotation to Supplier Karel de Groot 2011-04-01 18:32:00
# 616 Create Quotation comparison Map Francois de Perrier 2011-04-01 19:31:00
# 616 Analyze Quotation comparison Map Tesca Lobes 2011-04-02 04:10:00
# 616 Choose best option Nico Ojenbeer 2011-04-02 04:42:00
# 616 Settle conditions with supplier Magdalena Predutta 2011-04-02 22:51:00
# 616 Create Purchase Order Karel de Groot 2011-04-03 07:53:00
# 616 Confirm Purchase Order Esmeralda Clay 2011-04-05 03:52:00
# 616 Deliver Goods Services Karen Clarens 2011-04-08 07:35:00
# 616 Release Purchase Order Nico Ojenbeer 2011-04-08 20:43:00
# 616 Approve Purchase Order for payment Francois de Perrier 2011-04-09 13:33:00
# 616 Send invoice Kiu Kan 2011-04-11 22:40:00
# 616 Release Supplier's Invoice Karalda Nimwada 2011-04-12 13:04:00
# 616 Authorize Supplier's Invoice payment Karalda Nimwada 2011-04-12 13:14:00
# 616 Pay invoice Karalda Nimwada 2011-04-12 13:37:00
# 618 Create Purchase Requisition Christian Francois 2011-03-29 16:16:00
# 618 Create Request for Quotation Requester Anne Olwada 2011-03-30 01:15:00
# 618 Analyze Request for Quotation Magdalena Predutta 2011-04-01 02:20:00
# 618 Send Request for Quotation to Supplier Karel de Groot 2011-04-01 19:23:00
# 618 Create Quotation comparison Map Magdalena Predutta 2011-04-02 18:42:00
# 618 Analyze Quotation comparison Map Esmana Liubiata 2011-04-03 05:13:00
# 618 Choose best option Tesca Lobes 2011-04-03 05:42:00
# 618 Settle conditions with supplier Karel de Groot 2011-04-03 08:04:00
# 618 Create Purchase Order Francois de Perrier 2011-04-03 22:23:00
# 618 Confirm Purchase Order Carmen Finacse 2011-04-04 21:45:00
# 618 Deliver Goods Services Esmeralda Clay 2011-04-05 07:02:00
# 618 Release Purchase Order Christian Francois 2011-04-05 20:40:00
# 618 Approve Purchase Order for payment Karel de Groot 2011-04-09 12:45:00
# 618 Send invoice Carmen Finacse 2011-04-10 10:32:00
# 618 Release Supplier's Invoice Karalda Nimwada 2011-04-11 01:01:00
# 618 Authorize Supplier's Invoice payment Karalda Nimwada 2011-04-11 01:05:00
# 618 Pay invoice Pedro Alvares 2011-04-11 01:35:00
# 619 Create Purchase Requisition Miu Hanwan 2011-03-29 19:04:00
# 619 Create Request for Quotation Requester Clement Duchot 2011-03-30 01:47:00
# 619 Analyze Request for Quotation Francois de Perrier 2011-03-31 18:56:00
# 619 Send Request for Quotation to Supplier Karel de Groot 2011-04-02 12:46:00
# 619 Create Quotation comparison Map Francois de Perrier 2011-04-03 07:28:00
# 619 Analyze Quotation comparison Map Esmana Liubiata 2011-04-03 17:48:00
# 619 Choose best option Nico Ojenbeer 2011-04-03 18:19:00
# 619 Settle conditions with supplier Magdalena Predutta 2011-04-04 01:50:00
# 619 Create Purchase Order Magdalena Predutta 2011-04-04 20:21:00
# 619 Confirm Purchase Order Karen Clarens 2011-04-05 04:12:00
# 619 Deliver Goods Services Carmen Finacse 2011-04-07 14:32:00
# 619 Release Purchase Order Tesca Lobes 2011-04-09 19:20:00
# 619 Approve Purchase Order for payment Magdalena Predutta 2011-04-10 06:51:00
# 619 Send invoice Kiu Kan 2011-04-11 22:40:00
# 619 Release Supplier's Invoice Pedro Alvares 2011-04-12 13:05:00
# 619 Authorize Supplier's Invoice payment Karalda Nimwada 2011-04-12 13:14:00
# 619 Pay invoice Karalda Nimwada 2011-04-12 13:44:00
# 62 Create Purchase Requisition Anna Kaufmann 2011-01-08 19:09:00
# 62 Analyze Purchase Requisition Francis Odell 2011-01-09 17:42:00
# 62 Create Request for Quotation Requester Manager Francis Odell 2011-01-09 17:52:00
# 62 Analyze Request for Quotation Karel de Groot 2011-01-10 09:50:00
# 620 Create Purchase Requisition Clement Duchot 2011-03-30 14:30:00
# 620 Analyze Purchase Requisition Heinz Gutschmidt 2011-03-31 10:53:00
# 620 Create Request for Quotation Requester Manager Francis Odell 2011-03-31 11:09:00
# 620 Analyze Request for Quotation Karel de Groot 2011-04-02 10:33:00
# 620 Send Request for Quotation to Supplier Karel de Groot 2011-04-03 01:07:00
# 620 Create Quotation comparison Map Karel de Groot 2011-04-03 05:19:00
# 620 Analyze Quotation comparison Map Penn Osterwalder 2011-04-03 14:19:00
# 620 Choose best option Nico Ojenbeer 2011-04-03 14:34:00
# 620 Settle conditions with supplier Francois de Perrier 2011-04-04 10:13:00
# 620 Create Purchase Order Francois de Perrier 2011-04-04 15:19:00
# 620 Confirm Purchase Order Carmen Finacse 2011-04-04 22:50:00
# 620 Deliver Goods Services Esmeralda Clay 2011-04-05 13:14:00
# 620 Release Purchase Order Fjodor Kowalski 2011-04-07 06:05:00
# 620 Approve Purchase Order for payment Francois de Perrier 2011-04-08 07:15:00
# 620 Send invoice Sean Manney 2011-04-11 13:03:00
# 620 Release Supplier's Invoice Karalda Nimwada 2011-04-12 03:10:00
# 620 Authorize Supplier's Invoice payment Karalda Nimwada 2011-04-12 03:14:00
# 620 Pay invoice Pedro Alvares 2011-04-12 03:47:00
# 622 Create Purchase Requisition Fjodor Kowalski 2011-03-30 21:52:00
# 622 Analyze Purchase Requisition Maris Freeman 2011-03-31 18:36:00
# 623 Create Purchase Requisition Kim Passa 2011-03-30 23:55:00
# 623 Create Request for Quotation Requester Kim Passa 2011-03-31 08:17:00
# 623 Analyze Request for Quotation Karel de Groot 2011-04-01 01:01:00
# 623 Send Request for Quotation to Supplier Magdalena Predutta 2011-04-01 12:47:00
# 623 Create Quotation comparison Map Karel de Groot 2011-04-01 15:28:00
# 623 Analyze Quotation comparison Map Elvira Lores 2011-04-02 00:11:00
# 623 Choose best option Kim Passa 2011-04-02 00:34:00
# 623 Settle conditions with supplier Magdalena Predutta 2011-04-02 03:26:00
# 623 Create Purchase Order Karel de Groot 2011-04-03 01:25:00
# 623 Confirm Purchase Order Carmen Finacse 2011-04-04 23:09:00
# 623 Deliver Goods Services Karen Clarens 2011-04-05 07:27:00
# 623 Release Purchase Order Nico Ojenbeer 2011-04-05 19:11:00
# 623 Approve Purchase Order for payment Karel de Groot 2011-04-06 03:55:00
# 623 Send invoice Carmen Finacse 2011-04-07 14:09:00
# 623 Release Supplier's Invoice Pedro Alvares 2011-04-08 04:28:00
# 623 Authorize Supplier's Invoice payment Pedro Alvares 2011-04-08 04:32:00
# 623 Pay invoice Karalda Nimwada 2011-04-08 05:27:00
# 627 Create Purchase Requisition Tesca Lobes 2011-03-31 09:03:00
# 627 Analyze Purchase Requisition Maris Freeman 2011-04-01 09:56:00
# 627 Create Request for Quotation Requester Manager Maris Freeman 2011-04-01 10:08:00
# 627 Analyze Request for Quotation Francois de Perrier 2011-05-09 04:32:00
# 627 Amend Request for Quotation Requester Immanuel Karagianni 2011-05-09 05:55:00
# 627 Analyze Request for Quotation Francois de Perrier 2011-05-15 11:27:00
# 627 Amend Request for Quotation Requester Elvira Lores 2011-05-15 12:45:00
# 627 Analyze Request for Quotation Magdalena Predutta 2011-05-30 21:29:00
# 627 Amend Request for Quotation Requester Alberto Duport 2011-05-30 22:45:00
# 627 Analyze Request for Quotation Magdalena Predutta 2011-06-04 01:25:00
# 627 Send Request for Quotation to Supplier Magdalena Predutta 2011-06-04 15:34:00
# 627 Create Quotation comparison Map Karel de Groot 2011-06-04 20:41:00
# 627 Analyze Quotation comparison Map Kim Passa 2011-06-05 08:36:00
# 627 Choose best option Kim Passa 2011-06-05 09:03:00
# 627 Settle conditions with supplier Francois de Perrier 2011-06-05 14:58:00
# 627 Create Purchase Order Karel de Groot 2011-06-06 14:52:00
# 627 Confirm Purchase Order Kiu Kan 2011-06-08 17:35:00
# 627 Deliver Goods Services Carmen Finacse 2011-06-19 23:10:00
# 627 Release Purchase Order Alberto Duport 2011-06-21 13:45:00
# 627 Approve Purchase Order for payment Karel de Groot 2011-06-21 22:44:00
# 627 Send invoice Carmen Finacse 2011-06-22 17:48:00
# 627 Release Supplier's Invoice Karalda Nimwada 2011-06-23 08:10:00
# 627 Settle dispute with supplier Financial Manager Karalda Nimwada 2011-06-23 08:25:00
# 627 Authorize Supplier's Invoice payment Karalda Nimwada 2011-06-23 08:49:00
# 627 Pay invoice Pedro Alvares 2011-06-23 08:54:00
# 63 Create Purchase Requisition Anna Kaufmann 2011-01-08 22:57:00
# 63 Analyze Purchase Requisition Heinz Gutschmidt 2011-01-09 17:47:00
# 632 Create Purchase Requisition Nico Ojenbeer 2011-03-31 22:48:00
# 632 Analyze Purchase Requisition Heinz Gutschmidt 2011-04-01 17:50:00
# 632 Create Request for Quotation Requester Manager Maris Freeman 2011-04-01 18:01:00
# 632 Analyze Request for Quotation Karel de Groot 2011-04-04 22:35:00
# 632 Amend Request for Quotation Requester Fjodor Kowalski 2011-04-04 23:46:00
# 632 Analyze Request for Quotation Magdalena Predutta 2011-04-11 12:54:00
# 632 Amend Request for Quotation Requester Penn Osterwalder 2011-04-11 13:54:00
# 632 Analyze Request for Quotation Karel de Groot 2011-04-28 15:53:00
# 632 Amend Request for Quotation Requester Esmana Liubiata 2011-04-28 17:12:00
# 632 Analyze Request for Quotation Magdalena Predutta 2011-05-22 04:24:00
# 632 Amend Request for Quotation Requester Immanuel Karagianni 2011-05-22 06:06:00
# 632 Analyze Request for Quotation Magdalena Predutta 2011-06-14 13:28:00
# 632 Amend Request for Quotation Requester Nico Ojenbeer 2011-06-14 14:37:00
# 632 Analyze Request for Quotation Francois de Perrier 2011-06-25 09:09:00
# 632 Send Request for Quotation to Supplier Karel de Groot 2011-06-26 15:11:00
# 632 Create Quotation comparison Map Karel de Groot 2011-06-26 17:28:00
# 632 Analyze Quotation comparison Map Miu Hanwan 2011-06-27 06:04:00
# 632 Choose best option Miu Hanwan 2011-06-27 06:38:00
# 632 Settle conditions with supplier Karel de Groot 2011-06-27 11:25:00
# 632 Create Purchase Order Francois de Perrier 2011-06-28 12:30:00
# 632 Confirm Purchase Order Kiu Kan 2011-07-04 06:09:00
# 632 Deliver Goods Services Sean Manney 2011-07-09 16:36:00
# 632 Release Purchase Order Elvira Lores 2011-07-11 15:03:00
# 632 Approve Purchase Order for payment Magdalena Predutta 2011-07-11 19:36:00
# 632 Send invoice Kiu Kan 2011-07-13 15:49:00
# 632 Release Supplier's Invoice Pedro Alvares 2011-07-14 06:22:00
# 632 Authorize Supplier's Invoice payment Karalda Nimwada 2011-07-14 06:28:00
# 632 Pay invoice Karalda Nimwada 2011-07-14 06:52:00
# 633 Create Purchase Requisition Elvira Lores 2011-04-01 10:58:00
# 633 Create Request for Quotation Requester Alberto Duport 2011-04-01 15:40:00
# 633 Analyze Request for Quotation Karel de Groot 2011-04-02 12:06:00
# 635 Create Purchase Requisition Tesca Lobes 2011-04-01 23:16:00
# 635 Analyze Purchase Requisition Heinz Gutschmidt 2011-04-02 09:23:00
# 635 Create Request for Quotation Requester Manager Heinz Gutschmidt 2011-04-02 09:31:00
# 635 Analyze Request for Quotation Francois de Perrier 2011-04-11 08:50:00
# 635 Amend Request for Quotation Requester Esmana Liubiata 2011-04-11 10:14:00
# 635 Analyze Request for Quotation Francois de Perrier 2011-04-11 16:00:00
# 635 Amend Request for Quotation Requester Penn Osterwalder 2011-04-11 17:15:00
# 635 Analyze Request for Quotation Francois de Perrier 2011-05-11 15:41:00
# 635 Amend Request for Quotation Requester Miu Hanwan 2011-05-11 16:52:00
# 635 Analyze Request for Quotation Francois de Perrier 2011-06-18 13:06:00
# 635 Send Request for Quotation to Supplier Karel de Groot 2011-06-19 10:42:00
# 635 Create Quotation comparison Map Francois de Perrier 2011-06-19 12:45:00
# 635 Analyze Quotation comparison Map Elvira Lores 2011-06-19 20:36:00
# 635 Choose best option Kim Passa 2011-06-19 20:54:00
# 635 Settle conditions with supplier Karel de Groot 2011-06-19 23:46:00
# 635 Create Purchase Order Francois de Perrier 2011-06-20 21:10:00
# 635 Confirm Purchase Order Karen Clarens 2011-07-07 04:42:00
# 635 Deliver Goods Services Esmeralda Clay 2011-07-11 09:49:00
# 635 Release Purchase Order Esmana Liubiata 2011-07-13 16:14:00
# 635 Approve Purchase Order for payment Karel de Groot 2011-07-14 08:37:00
# 635 Send invoice Karen Clarens 2011-07-16 19:09:00
# 635 Release Supplier's Invoice Pedro Alvares
# 2011-07-17 09:29:00
# 635 Authorize Supplier's Invoice payment Pedro Alvares 2011-07-17 09:35:00
# 635 Pay invoice Karalda Nimwada 2011-07-17 10:39:00
# 637 Create Purchase Requisition Clement Duchot 2011-04-02 14:24:00
# 637 Analyze Purchase Requisition Heinz Gutschmidt 2011-04-03 02:12:00
# 637 Create Request for Quotation Requester Manager Maris Freeman 2011-04-03 02:22:00
# 637 Analyze Request for Quotation Francois de Perrier 2011-04-05 06:34:00
# 637 Amend Request for Quotation Requester Immanuel Karagianni 2011-04-05 07:55:00
# 637 Analyze Request for Quotation Magdalena Predutta 2011-04-17 00:13:00
# 637 Amend Request for Quotation Requester Anne Olwada 2011-04-17 01:27:00
# 637 Analyze Request for Quotation Karel de Groot 2011-04-21 21:50:00
# 637 Amend Request for Quotation Requester Penn Osterwalder 2011-04-21 23:12:00
# 637 Analyze Request for Quotation Karel de Groot 2011-05-03 23:55:00
# 637 Amend Request for Quotation Requester Alberto Duport 2011-05-04 01:08:00
# 637 Analyze Request for Quotation Magdalena Predutta 2011-05-04 16:00:00
# 637 Amend Request for Quotation Requester Manager Heinz Gutschmidt 2011-05-05 07:58:00
# 637 Analyze Request for Quotation Francois de Perrier 2011-05-09 05:04:00
# 637 Amend Request for Quotation Requester Penn Osterwalder 2011-05-09 06:19:00
# 637 Analyze Request for Quotation Magdalena Predutta 2011-05-17 16:29:00
# 637 Amend Request for Quotation Requester Manager Maris Freeman 2011-05-18 08:56:00
# 637 Analyze Request for Quotation Karel de Groot 2011-05-21 18:46:00
# 637 Amend Request for Quotation Requester Esmana Liubiata 2011-05-21 20:03:00
# 637 Analyze Request for Quotation Karel de Groot 2011-06-18 15:16:00
# 637 Send Request for Quotation to Supplier Karel de Groot 2011-06-18 20:16:00
# 637 Create Quotation comparison Map Karel de Groot 2011-06-19 05:19:00
# 637 Analyze Quotation comparison Map Christian Francois 2011-06-19 18:04:00
# 637 Choose best option Immanuel Karagianni 2011-06-19 18:24:00
# 637 Settle conditions with supplier Magdalena Predutta 2011-06-20 07:55:00
# 637 Create Purchase Order Karel de Groot 2011-06-20 21:58:00
# 637 Confirm Purchase Order Sean Manney 2011-06-22 09:29:00
# 637 Deliver Goods Services Esmeralda Clay 2011-06-24 10:10:00
# 637 Release Purchase Order Elvira Lores 2011-06-26 08:49:00
# 637 Approve Purchase Order for payment Karel de Groot 2011-06-26 15:31:00
# 637 Send invoice Kiu Kan 2011-06-27 04:36:00
# 637 Release Supplier's Invoice Pedro Alvares 2011-06-27 19:08:00
# 637 Settle dispute with supplier Financial Manager Pedro Alvares 2011-06-27 20:09:00
# 637 Authorize Supplier's Invoice payment Karalda Nimwada 2011-06-27 20:33:00
# 637 Pay invoice Pedro Alvares 2011-06-27 20:48:00
# 64 Create Purchase Requisition Fjodor Kowalski 2011-01-08 23:04:00
# 64 Create Request for Quotation Requester Penn Osterwalder 2011-01-09 03:37:00
# ...
# 93 Amend Request for Quotation Requester Miu Hanwan 2011-01-17 03:05:00
# 93 Analyze Request for Quotation Francois de Perrier 2011-01-17 05:20:00
# 93 Send Request for Quotation to Supplier Magdalena Predutta 2011-01-18 02:25:00
# 93 Create Quotation comparison Map Magdalena Predutta 2011-01-18 19:07:00
# 93 Analyze Quotation comparison Map Clement Duchot 2011-01-19 05:08:00
# 93 Choose best option Anna Kaufmann 2011-01-19 05:37:00
# 93 Settle conditions with supplier Magdalena Predutta 2011-01-20 08:09:00
# 93 Create Purchase Order Francois de Perrier 2011-01-21 18:52:00
# 93 Confirm Purchase Order Carmen Finacse 2011-01-22 06:22:00
# 93 Deliver Goods Services Carmen Finacse 2011-01-23 21:55:00
# 93 Release Purchase Order Nico Ojenbeer 2011-01-25 18:00:00
# 93 Approve Purchase Order for payment Magdalena Predutta 2011-01-26 03:28:00
# 93 Send invoice Kiu Kan 2011-01-26 10:50:00
# 93 Release Supplier's Invoice Karalda Nimwada 2011-01-27 01:12:00
# 93 Authorize Supplier's Invoice payment Karalda Nimwada 2011-01-27 01:15:00
# 93 Pay invoice Karalda Nimwada 2011-01-27 01:58:00
# 931 Create Purchase Requisition Penn Osterwalder 2011-05-16 09:54:00
# 931 Analyze Purchase Requisition Francis Odell 2011-05-17 08:33:00
# 931 Create Request for Quotation Requester Manager Heinz Gutschmidt 2011-05-17 08:48:00
# 931 Analyze Request for Quotation Magdalena Predutta 2011-05-21 19:04:00
# 931 Send Request for Quotation to Supplier Francois de Perrier 2011-05-22 03:00:00
# 931 Create Quotation comparison Map Karel de Groot 2011-05-22 05:13:00
# 931 Analyze Quotation comparison Map Esmana Liubiata 2011-05-22 16:20:00
# 931 Choose best option Nico Ojenbeer 2011-05-22 16:47:00
# 931 Settle conditions with supplier Francois de Perrier 2011-05-23 10:05:00
# 931 Create Purchase Order Karel de Groot 2011-05-24 08:39:00
# 931 Confirm Purchase Order Kiu Kan 2011-05-24 20:44:00
# 931 Deliver Goods Services Esmeralda Clay 2011-05-25 11:46:00
# 931 Release Purchase Order Penn Osterwalder 2011-05-26 08:50:00
# 931 Approve Purchase Order for payment Francois de Perrier 2011-05-27 14:25:00
# 931 Send invoice Karen Clarens 2011-05-29 06:19:00
# 931 Release Supplier's Invoice Karalda Nimwada 2011-05-29 20:39:00
# 931 Authorize Supplier's Invoice payment Pedro Alvares 2011-05-29 20:44:00
# 931 Pay invoice Pedro Alvares 2011-05-29 20:49:00
# 935 Create Purchase Requisition Anne Olwada 2011-05-16 15:21:00
# 935 Create Request for Quotation Requester Tesca Lobes 2011-05-16 16:07:00
# 935 Analyze Request for Quotation Magdalena Predutta 2011-05-18 23:35:00
# 935 Send Request for Quotation to Supplier Karel de Groot 2011-05-19 07:50:00
# 935 Create Quotation comparison Map Francois de Perrier 2011-05-20 04:51:00
# 935 Analyze Quotation comparison Map Clement Duchot 2011-05-20 12:35:00
# 935 Choose best option Penn Osterwalder 2011-05-20 13:00:00
# 935 Settle conditions with supplier Karel de Groot 2011-05-21 01:16:00
# 935 Create Purchase Order Francois de Perrier 2011-05-21 18:30:00
# 935 Confirm Purchase Order Esmeralda Clay 2011-05-23 04:56:00
# 935 Deliver Goods Services Esmeralda Clay 2011-05-24 13:46:00
# 935 Release Purchase Order Kim Passa 2011-05-25 19:36:00
# 935 Approve Purchase Order for payment Francois de Perrier 2011-05-26 06:27:00
# 935 Send invoice Karen Clarens 2011-05-26 12:56:00
# 935 Release Supplier's Invoice Pedro Alvares 2011-05-27 03:15:00
# 935 Authorize Supplier's Invoice payment Karalda Nimwada 2011-05-27 03:18:00
# 935 Pay invoice Karalda Nimwada 2011-05-27 03:28:00
# 94 Create Purchase Requisition Nico Ojenbeer 2011-01-12 23:39:00
# 94 Create Request for Quotation Requester Immanuel Karagianni 2011-01-13 01:49:00
# 94 Analyze Request for Quotation Magdalena Predutta 2011-01-17 02:39:00
# 94 Amend Request for Quotation Requester Anna Kaufmann 2011-01-17 04:02:00
# 94 Analyze Request for Quotation Francois de Perrier 2011-01-17 05:29:00
# 94 Send Request for Quotation to Supplier Magdalena Predutta 2011-01-18 18:30:00
# 94 Create Quotation comparison Map Karel de Groot 2011-01-18 21:37:00
# 94 Analyze Quotation comparison Map Kim Passa 2011-01-19 06:47:00
# 94 Choose best option Clement Duchot 2011-01-19 06:58:00
# 94 Settle conditions with supplier Karel de Groot 2011-01-19 11:01:00
# 94 Create Purchase Order Karel de Groot 2011-01-21 18:55:00
# 94 Confirm Purchase Order Kiu Kan 2011-01-22 07:02:00
# 94 Deliver Goods Services Karen Clarens 2011-01-24 16:37:00
# 94 Release Purchase Order Miu Hanwan 2011-01-25 03:51:00
# 94 Approve Purchase Order for payment Karel de Groot 2011-01-25 15:45:00
# 94 Send invoice Carmen Finacse 2011-01-27 07:55:00
# 94 Release Supplier's Invoice Pedro Alvares 2011-01-27 22:20:00
# 94 Authorize Supplier's Invoice payment Karalda Nimwada 2011-01-27 22:24:00
# 94 Pay invoice Karalda Nimwada 2011-01-27 22:50:00
# 940 Create Purchase Requisition Immanuel Karagianni 2011-05-17 06:31:00
# 940 Create Request for Quotation Requester Esmana Liubiata 2011-05-17 09:58:00
# 940 Analyze Request for Quotation Francois de Perrier 2011-05-18 19:30:00
# 940 Send Request for Quotation to Supplier Magdalena Predutta 2011-05-18 23:46:00
# 940 Create Quotation comparison Map Francois de Perrier 2011-05-19 03:44:00
# 940 Analyze Quotation comparison Map Kim Passa 2011-05-19 15:38:00
# 940 Choose best option Anna Kaufmann 2011-05-19 15:52:00
# 940 Settle conditions with supplier Magdalena Predutta 2011-05-20 23:31:00
# 940 Create Purchase Order Francois de Perrier 2011-05-21 18:48:00
# 940 Confirm Purchase Order Esmeralda Clay 2011-05-22 11:33:00
# 940 Deliver Goods Services Esmeralda Clay 2011-05-23 05:32:00
# 940 Release Purchase Order Kim Passa 2011-05-24 20:59:00
# 940 Approve Purchase Order for payment Karel de Groot 2011-05-26 07:41:00
# 940 Send invoice Kiu Kan 2011-05-28 01:11:00
# 940 Authorize Supplier's Invoice payment Pedro Alvares 2011-05-28 15:28:00
# 940 Pay invoice Karalda Nimwada 2011-05-28 16:11:00
# 948 Create Purchase Requisition Clement Duchot 2011-05-17 22:06:00
# 948 Analyze Purchase Requisition Heinz Gutschmidt 2011-05-18 10:44:00
# 949 Create Purchase Requisition Esmana Liubiata 2011-05-17 22:11:00
# 949 Analyze Purchase Requisition Maris Freeman 2011-05-18 15:19:00
# 949 Create Request for Quotation Requester Manager Maris Freeman 2011-05-18 15:33:00
# 949 Analyze Request for Quotation Francois de Perrier 2011-06-05 02:58:00
# 949 Amend Request for Quotation Requester Tesca Lobes 2011-06-05 04:20:00
# 949 Analyze Request for Quotation Francois de Perrier 2011-06-21 18:42:00
# 949 Amend Request for Quotation Requester Immanuel Karagianni 2011-06-21 19:48:00
# 949 Analyze Request for Quotation Francois de Perrier 2011-07-18 10:05:00
# 949 Send Request for Quotation to Supplier Francois de Perrier 2011-07-20 10:25:00
# 949 Create Quotation comparison Map Francois de Perrier 2011-07-20 10:54:00
# 949 Analyze Quotation comparison Map Penn Osterwalder 2011-07-20 19:26:00
# 949 Choose best option Fjodor Kowalski 2011-07-20 19:49:00
# 949 Settle conditions with supplier Francois de Perrier 2011-07-21 06:37:00
# 949 Create Purchase Order Magdalena Predutta 2011-07-22 02:37:00
# 949 Confirm Purchase Order Kiu Kan 2011-08-03 10:50:00
# 949 Deliver Goods Services Esmeralda Clay 2011-08-11 13:07:00
# 949 Release Purchase Order Nico Ojenbeer 2011-08-13 13:32:00
# 949 Approve Purchase Order for payment Francois de Perrier 2011-08-13 23:29:00
# 949 Send invoice Esmeralda Clay 2011-08-20 08:39:00
# 949 Release Supplier's Invoice Pedro Alvares 2011-08-20 22:58:00
# 949 Settle dispute with supplier Financial Manager Pedro Alvares 2011-08-20 23:41:00
# 949 Authorize Supplier's Invoice payment Karalda Nimwada 2011-08-21 00:09:00
# 949 Pay invoice Pedro Alvares 2011-08-21 00:33:00
# 950 Create Purchase Requisition Elvira Lores 2011-05-17 23:09:00
# 950 Create Request for Quotation Requester Esmana Liubiata 2011-05-18 05:22:00
# 950 Analyze Request for Quotation Magdalena Predutta 2011-05-28 05:19:00
# 96 Create Purchase Requisition Christian Francois 2011-01-13 02:33:00
# 96 Create Request for Quotation Requester Anne Olwada 2011-01-13 03:30:00
# 96 Analyze Request for Quotation Karel de Groot 2011-01-13 07:31:00
# 96 Amend Request for Quotation Requester Christian Francois 2011-01-13 09:11:00
# 96 Analyze Request for Quotation Magdalena Predutta 2011-01-14 09:50:00
# 96 Send Request for Quotation to Supplier Karel de Groot 2011-01-15 02:29:00
# 96 Create Quotation comparison Map Magdalena Predutta 2011-01-15 10:35:00
# 96 Analyze Quotation comparison Map Elvira Lores 2011-01-15 20:07:00
# 96 Choose best option Fjodor Kowalski 2011-01-15 20:38:00
# 96 Settle conditions with supplier Karel de Groot 2011-01-15 23:01:00
# 96 Create Purchase Order Karel de Groot 2011-01-16 21:05:00
# 96 Confirm Purchase Order Kiu Kan 2011-01-17 04:44:00
# 96 Deliver Goods Services Sean Manney 2011-01-20 04:04:00
# 96 Release Purchase Order Elvira Lores 2011-01-21 04:17:00
# 96 Approve Purchase Order for payment Magdalena Predutta 2011-01-21 18:14:00
# 96 Send invoice Carmen Finacse 2011-01-22 07:58:00
# 96 Release Supplier's Invoice Pedro Alvares 2011-01-22 22:21:00
# 96 Settle dispute with supplier Financial Manager Pedro Alvares 2011-01-22 23:11:00
# 96 Authorize Supplier's Invoice payment Karalda Nimwada 2011-01-22 23:28:00
# 96 Pay invoice Pedro Alvares 2011-01-22 23:42:00
# 972 Create Purchase Requisition Anna Kaufmann 2011-05-22 05:37:00
# 972 Analyze Purchase Requisition Francis Odell 2011-05-23 01:41:00
# 975 Create Purchase Requisition Esmana Liubiata 2011-05-22 08:13:00
# 975 Analyze Purchase Requisition Heinz Gutschmidt 2011-05-23 06:44:00
# 976 Create Purchase Requisition Esmana Liubiata 2011-05-22 08:37:00
# 976 Create Request for Quotation Requester Anne Olwada 2011-05-22 10:25:00
# 976 Analyze Request for Quotation Karel de Groot 2011-06-06 14:28:00
# 976 Amend Request for Quotation Requester Anne Olwada 2011-06-06 15:35:00
# 976 Analyze Request for Quotation Francois de Perrier 2011-07-09 21:49:00
# 976 Amend Request for Quotation Requester Christian Francois 2011-07-09 23:04:00
# 976 Analyze Request for Quotation Francois de Perrier 2011-08-14 10:56:00
# 976 Amend Request for Quotation Requester Esmana Liubiata 2011-08-14 12:22:00
# 976 Analyze Request for Quotation Magdalena Predutta 2011-08-14 22:11:00
# 976 Send Request for Quotation to Supplier Francois de Perrier 2011-08-15 07:11:00
# 976 Create Quotation comparison Map Francois de Perrier 2011-08-15 22:42:00
# 976 Analyze Quotation comparison Map Elvira Lores 2011-08-16 06:11:00
# 976 Choose best option Alberto Duport 2011-08-16 06:34:00
# 976 Settle conditions with supplier Karel de Groot 2011-08-16 11:18:00
# 976 Create Purchase Order Karel de Groot 2011-08-16 18:15:00
# 976 Confirm Purchase Order Esmeralda Clay 2011-08-18 02:57:00
# 976 Deliver Goods Services Carmen Finacse 2011-08-20 07:54:00
# 976 Release Purchase Order Tesca Lobes 2011-08-21 12:45:00
# 976 Approve Purchase Order for payment Magdalena Predutta 2011-08-22 06:02:00
# 976 Send invoice Esmeralda Clay 2011-08-23 03:16:00
# 976 Release Supplier's Invoice Pedro Alvares 2011-08-23 17:46:00
# 976 Authorize Supplier's Invoice payment Pedro Alvares 2011-08-23 17:48:00
# 976 Pay invoice Karalda Nimwada 2011-08-23 18:08:00
# 98 Create Purchase Requisition Immanuel Karagianni 2011-01-13 08:37:00
# 98 Analyze Purchase Requisition Maris Freeman 2011-01-13 21:08:00
# 98 Create Request for Quotation Requester Manager Francis Odell 2011-01-13 21:18:00
# 98 Analyze Request for Quotation Francois de Perrier 2011-01-16 17:39:00
# 98 Amend Request for Quotation Requester Penn Osterwalder 2011-01-16 18:57:00
# 98 Analyze Request for Quotation Karel de Groot 2011-01-17 01:27:00
# 98 Amend Request for Quotation Requester Miu Hanwan 2011-01-17 02:46:00
# 98 Analyze Request for Quotation Magdalena Predutta 2011-01-17 04:46:00
# 98 Send Request for Quotation to Supplier Magdalena Predutta 2011-01-18 18:45:00
# 98 Create Quotation comparison Map Karel de Groot 2011-01-19 00:57:00
# 98 Analyze Quotation comparison Map Fjodor Kowalski 2011-01-19 13:37:00
# 98 Choose best option Fjodor Kowalski 2011-01-19 14:01:00
# 98 Settle conditions with supplier Karel de Groot 2011-01-21 04:42:00
# 98 Create Purchase Order Francois de Perrier 2011-01-22 01:32:00
# 98 Confirm Purchase Order Carmen Finacse 2011-01-22 06:00:00
# 98 Deliver Goods Services Carmen Finacse 2011-01-22 14:29:00
# 98 Release Purchase Order Elvira Lores 2011-01-24 05:02:00
# 98 Settle dispute with supplier Purchasing Agent Francois de Perrier 2011-01-24 11:52:00
# 98 Release Purchase Order Tesca Lobes 2011-01-25 04:19:00
# 98 Approve Purchase Order for payment Karel de Groot 2011-01-25 14:54:00
# 98 Send invoice Carmen Finacse 2011-01-27 08:33:00
# 98 Release Supplier's Invoice Karalda Nimwada 2011-01-27 23:02:00
# 98 Authorize Supplier's Invoice payment Karalda Nimwada 2011-01-27 23:05:00
# 98 Pay invoice Karalda Nimwada 2011-01-27 23:51:00
# 981 Create Purchase Requisition Anna Kaufmann 2011-05-23 01:47:00
# 981 Analyze Purchase Requisition Francis Odell 2011-05-24 01:04:00
# 981 Create Request for Quotation Requester Manager Francis Odell 2011-05-24 01:17:00
# 981 Analyze Request for Quotation Karel de Groot 2011-05-26 13:34:00
# 981 Send Request for Quotation to Supplier Magdalena Predutta 2011-05-27 15:25:00
# 981 Create Quotation comparison Map Magdalena Predutta 2011-05-28 05:39:00
# 981 Analyze Quotation comparison Map Tesca Lobes 2011-05-28 16:12:00
# 981 Choose best option Tesca Lobes 2011-05-28 16:33:00
# 981 Settle conditions with supplier Francois de Perrier 2011-05-29 10:09:00
# 981 Create Purchase Order Magdalena Predutta 2011-05-30 13:10:00
# 981 Confirm Purchase Order Carmen Finacse 2011-06-04 09:03:00
# 981 Deliver Goods Services Esmeralda Clay 2011-06-05 06:49:00
# 981 Release Purchase Order Fjodor Kowalski 2011-06-06 23:42:00
# 981 Approve Purchase Order for payment Francois de Perrier 2011-06-07 02:07:00
# 981 Send invoice Carmen Finacse 2011-06-07 10:37:00
# 981 Release Supplier's Invoice Karalda Nimwada 2011-06-08 00:55:00
# 981 Settle dispute with supplier Financial Manager Karalda Nimwada 2011-06-08 01:53:00
# 981 Authorize Supplier's Invoice payment Pedro Alvares 2011-06-08 02:21:00
# 981 Pay invoice Pedro Alvares 2011-06-08 03:10:00
# 988 Create Purchase Requisition Immanuel Karagianni 2011-05-23 12:59:00
# 988 Create Request for Quotation Requester Anne Olwada 2011-05-23 21:17:00
# 988 Analyze Request for Quotation Francois de Perrier 2011-06-01 09:36:00
# 99 Create Purchase Requisition Anna Kaufmann 2011-01-13 10:03:00
# 99 Analyze Purchase Requisition Maris Freeman 2011-01-13 20:19:00
# 99 Create Request for Quotation Requester Manager Heinz Gutschmidt 2011-01-13 20:26:00
# 99 Analyze Request for Quotation Karel de Groot 2011-01-16 23:32:00
# 99 Amend Request for Quotation Requester Penn Osterwalder 2011-01-17 00:52:00
# 99 Analyze Request for Quotation Francois de Perrier 2011-01-17 02:35:00
# 99 Send Request for Quotation to Supplier Magdalena Predutta 2011-01-17 05:37:00
# 99 Create Quotation comparison Map Francois de Perrier 2011-01-17 06:42:00
# 99 Analyze Quotation comparison Map Christian Francois 2011-01-17 18:51:00
# 99 Choose best option Immanuel Karagianni 2011-01-17 19:01:00
# 99 Settle conditions with supplier Francois de Perrier 2011-01-17 22:39:00
# 99 Create Purchase Order Magdalena Predutta 2011-01-18 17:50:00
# 99 Confirm Purchase Order Sean Manney 2011-01-19 00:16:00
# 99 Deliver Goods Services Kiu Kan 2011-01-19 10:42:00
# 99 Release Purchase Order Nico Ojenbeer 2011-01-20 19:50:00
# 99 Approve Purchase Order for payment Francois de Perrier 2011-01-21 10:57:00
# 99 Send invoice Kiu Kan 2011-01-22 07:30:00
# 99 Release Supplier's Invoice Karalda Nimwada 2011-01-22 21:51:00
# 99 Authorize Supplier's Invoice payment Karalda Nimwada 2011-01-22 21:56:00
# 99 Pay invoice Pedro Alvares 2011-01-22 22:43:00
# 993 Create Purchase Requisition Christian Francois 2011-05-24 16:18:00
# 993 Analyze Purchase Requisition Francis Odell 2011-05-25 15:24:00
# 997 Create Purchase Requisition Kim Passa 2011-05-25 04:20:00
# 997 Analyze Purchase Requisition Maris Freeman 2011-05-25 15:25:00
# 997 Create Request for Quotation Requester Manager Maris Freeman 2011-05-25 15:32:00
# 997 Analyze Request for Quotation Magdalena Predutta 2011-05-29 10:18:00
# WARNING: 9 intermediate output messages were discarded.
# WARNING: some intermediate output was truncated.

# %%
# Listing 11 Implementing the control-flow algorithm in Python

F = dict()
for caseid in log:
    for i in range(0, len(log[caseid])-1):
        ai = log[caseid][i][0]
        aj = log[caseid][i+1][0] 
        if ai not in F:
            F[ai] = dict()
        if aj not in F[ai]:
            F[ai][aj] = 0
        F[ai][aj] += 1

for ai in sorted(F.keys()):
    for aj in sorted(F[ai].keys()):
        print ai, '->', aj, ':', F[ai][aj]
# Out:
# Amend Purchase Requisition -> Analyze Purchase Requisition : 8
# Amend Purchase Requisition -> Create Request for Quotation Requester : 3
# Amend Request for Quotation Requester -> Analyze Request for Quotation : 514
# Amend Request for Quotation Requester Manager -> Analyze Request for Quotation : 49
# Analyze Purchase Requisition -> Amend Purchase Requisition : 11
# Analyze Purchase Requisition -> Create Request for Quotation Requester Manager : 307
# Analyze Quotation comparison Map -> Choose best option : 413
# Analyze Request for Quotation -> Amend Request for Quotation Requester : 514
# Analyze Request for Quotation -> Amend Request for Quotation Requester Manager : 49
# Analyze Request for Quotation -> Send Request for Quotation to Supplier : 413
# Approve Purchase Order for payment -> Send invoice : 413
# Authorize Supplier's Invoice payment -> Pay invoice : 413
# Choose best option -> Settle conditions with supplier : 413
# Confirm Purchase Order -> Deliver Goods Services : 413
# Create Purchase Order -> Confirm Purchase Order : 413
# Create Purchase Requisition -> Analyze Purchase Requisition : 374
# Create Purchase Requisition -> Create Request for Quotation Requester : 234
# Create Quotation comparison Map -> Analyze Quotation comparison Map : 413
# Create Request for Quotation Requester -> Analyze Request for Quotation : 237
# Create Request for Quotation Requester Manager -> Analyze Request for Quotation : 307
# Deliver Goods Services -> Release Purchase Order : 413
# Release Purchase Order -> Approve Purchase Order for payment : 413
# Release Purchase Order -> Settle dispute with supplier Purchasing Agent : 26
# Release Supplier's Invoice -> Authorize Supplier's Invoice payment : 323
# Release Supplier's Invoice -> Settle dispute with supplier Financial Manager : 80
# Send Request for Quotation to Supplier -> Create Quotation comparison Map : 413
# Send invoice -> Authorize Supplier's Invoice payment : 10
# Send invoice -> Release Supplier's Invoice : 403
# Settle conditions with supplier -> Create Purchase Order : 413
# Settle dispute with supplier Financial Manager -> Authorize Supplier's Invoice payment : 80
# Settle dispute with supplier Purchasing Agent -> Release Purchase Order : 26

# %%
import graphviz as gv

G = gv.Digraph(strict=False)
G.graph_attr['rankdir'] = 'LR'
G.node_attr['shape'] = 'box'

F = dict()
for caseid in log:
    for i in range(0, len(log[caseid])-1):
        ai = log[caseid][i][0]
        aj = log[caseid][i+1][0] 
        if ai not in F:
            F[ai] = dict()
        if aj not in F[ai]:
            F[ai][aj] = 0
        F[ai][aj] += 1

A = dict()
for caseid in log:
    for i in range(0, len(log[caseid])):
        ai = log[caseid][i][0]
        if ai not in A:
            A[ai] = 0
        A[ai] += 1

x_min = min(A.values())
x_max = max(A.values())
for ai in A:
    text = ai + '\n(' + str(A[ai]) + ')'
    gray = int(float(x_max - A[ai]) / float(x_max - x_min) * 100.)
    fill = 'gray' + str(gray)
    font = 'black'
    if gray < 50:
        font = 'white'
    G.node(ai, label=text, style='filled', fillcolor=fill, fontcolor=font)

values = [F[ai][aj] for ai in F for aj in F[ai]]
x_min = min(values)
x_max = max(values)
y_min = 1.0
y_max = 5.0
for ai in F:
    for aj in F[ai]:
        x = F[ai][aj]
        y = y_min + (y_max-y_min) * float(x-x_min) / float(x_max-x_min)
        G.edge(ai, aj, label=str(x), penwidth=str(y))

G

# %%
# Listing 32 Calculating the average timestamp difference for each transition
D = dict()
for caseid in log:
    for i in range(0,len(log[caseid])-1):
        (ai,_,ti) = log[caseid][i]
        (aj,_,tj) = log[caseid][i+1]
        if ai not in D:
            D[ai] = dict()
        if aj not in D[ai]:
            D[ai][aj] = []
        D[ai][aj].append(tj-ti)
        
for ai in sorted(D.keys()):
    for aj in sorted(D[ai].keys()):
        sum_td = sum(D[ai][aj], datetime.timedelta(0))
        count_td = len(D[ai][aj])
        avg_td = sum_td/count_td
        avg_td -= datetime.timedelta(microseconds=avg_td.microseconds)
        D[ai][aj] = avg_td
        print ai, '->', aj, ':', D[ai][aj]
# Out:
# Amend Purchase Requisition -> Analyze Purchase Requisition : 18:12:30
# Amend Purchase Requisition -> Create Request for Quotation Requester : 4:52:20
# Amend Request for Quotation Requester -> Analyze Request for Quotation : 8 days, 12:35:49
# Amend Request for Quotation Requester Manager -> Analyze Request for Quotation : 10 days, 13:22:52
# Analyze Purchase Requisition -> Amend Purchase Requisition : 11:51:54
# Analyze Purchase Requisition -> Create Request for Quotation Requester Manager : 0:12:07
# Analyze Quotation comparison Map -> Choose best option : 0:20:09
# Analyze Request for Quotation -> Amend Request for Quotation Requester : 1:13:00
# Analyze Request for Quotation -> Amend Request for Quotation Requester Manager : 16:22:41
# Analyze Request for Quotation -> Send Request for Quotation to Supplier : 17:08:27
# Approve Purchase Order for payment -> Send invoice : 1 day, 22:54:06
# Authorize Supplier's Invoice payment -> Pay invoice : 0:35:10
# Choose best option -> Settle conditions with supplier : 12:03:05
# Confirm Purchase Order -> Deliver Goods Services : 2 days, 20:05:05
# Create Purchase Order -> Confirm Purchase Order : 1 day, 19:18:11
# Create Purchase Requisition -> Analyze Purchase Requisition : 17:40:23
# Create Purchase Requisition -> Create Request for Quotation Requester : 4:35:35
# Create Quotation comparison Map -> Analyze Quotation comparison Map : 10:03:21
# Create Request for Quotation Requester -> Analyze Request for Quotation : 6 days, 3:38:08
# Create Request for Quotation Requester Manager -> Analyze Request for Quotation : 4 days, 6:30:18
# Deliver Goods Services -> Release Purchase Order : 1 day, 8:54:41
# Release Purchase Order -> Approve Purchase Order for payment : 14:40:35
# Release Purchase Order -> Settle dispute with supplier Purchasing Agent : 7:49:50
# Release Supplier's Invoice -> Authorize Supplier's Invoice payment : 0:05:00
# Release Supplier's Invoice -> Settle dispute with supplier Financial Manager : 0:35:58
# Send Request for Quotation to Supplier -> Create Quotation comparison Map : 7:54:02
# Send invoice -> Authorize Supplier's Invoice payment : 14:23:54
# Send invoice -> Release Supplier's Invoice : 14:20:38
# Settle conditions with supplier -> Create Purchase Order : 19:15:07
# Settle dispute with supplier Financial Manager -> Authorize Supplier's Invoice payment : 0:24:04
# Settle dispute with supplier Purchasing Agent -> Release Purchase Order : 16:48:04

# %%
# Listing 34 Drawing the graph with average timestamp differences

import graphviz as gv

G = gv.Digraph(strict=False)

G.graph_attr['rankdir'] = 'LR'
G.node_attr['shape'] = 'box'

D = dict()
for caseid in log:
    for i in range(0,len(log[caseid])-1):
        (ai,_,ti) = log[caseid][i]
        (aj,_,tj) = log[caseid][i+1]
        if ai not in D:
            D[ai] = dict()
        if aj not in D[ai]:
            D[ai][aj] = []
        D[ai][aj].append(tj-ti)

for ai in sorted(D.keys()):
    for aj in sorted(D[ai].keys()):
        sum_td = sum(D[ai][aj], datetime.timedelta(0))
        count_td = len(D[ai][aj])
        avg_td = sum_td/count_td
        avg_td -= datetime.timedelta(microseconds=avg_td.microseconds)
        D[ai][aj] = avg_td

values = [D[ai][aj].total_seconds() for ai in D for aj in D[ai]]
x_min = min(values)
x_max = max(values)

y_min = 1.0
y_max = 5.0

for ai in D:
    for aj in D[ai]:
        x = D[ai][aj].total_seconds()
        y = y_min + (y_max-y_min) * float(x-x_min) / float(x_max-x_min)
        G.edge(ai, aj, label=str(D[ai][aj]), penwidth=str(y))

G

# %% [markdown]
# Organizational mining
# =====================

# %% [markdown]
# > *Handover* measure

# %%
# Listing 20 Implementing the handover-of-work algorithm in Python

H = dict()

for caseid in log:
    for i in range(0, len(log[caseid])-1):
        ui = log[caseid][i][1]
        uj = log[caseid][i+1][1]
        if ui not in H:
            H[ui] = dict()
        if uj not in H[ui]:
            H[ui][uj] = 0
        H[ui][uj] += 1

# %%
# Listing 21 Generating the output graph with Graphviz

import graphviz as pg

G = gv.Digraph(strict=False)

G.graph_attr['rankdir'] = 'LR'
G.node_attr['shape'] = 'circle'

values = [H[ui][uj] for ui in H for uj in H[ui]]
x_min = min(values)
x_max = max(values)

y_min = 1.0
y_max = 5.0

for ui in H:
    for uj in H[ui]:
        x = H[ui][uj]
        y = y_min + (y_max-y_min) * float(x-x_min) / float(x_max-x_min)
        G.edge(ui, uj, label=str(x), penwidth=str(y))

G

# %% [markdown]
# > Working together measure

# %%
# Listing 22 Implementing the working together algorithm
W = dict()

for caseid in log:
    S = set()
    for i in range(0, len(log[caseid])):
        ui = log[caseid][i][1]
        S.add(ui)
    S = sorted(list(S))
    for i in range(0, len(S)-1):
        for j in range(i+1, len(S)):
            ui = S[i]
            uj = S[j]
            if ui not in W:
                W[ui] = dict()
            if uj not in W[ui]:
                W[ui][uj] = 0
            W[ui][uj] += 1

for ui in sorted(W.keys()):
    for uj in sorted(W[ui].keys()):
        print ui, '--', uj, ':', W[ui][uj]
# Out:
# Alberto Duport -- Anna Kaufmann : 37
# Alberto Duport -- Anne Olwada : 45
# Alberto Duport -- Carmen Finacse : 68
# Alberto Duport -- Christian Francois : 43
# Alberto Duport -- Clement Duchot : 47
# Alberto Duport -- Elvira Lores : 38
# Alberto Duport -- Esmana Liubiata : 35
# Alberto Duport -- Esmeralda Clay : 65
# Alberto Duport -- Fjodor Kowalski : 42
# Alberto Duport -- Francis Odell : 60
# Alberto Duport -- Francois de Perrier : 130
# Alberto Duport -- Heinz Gutschmidt : 55
# Alberto Duport -- Immanuel Karagianni : 46
# Alberto Duport -- Karalda Nimwada : 110
# Alberto Duport -- Karel de Groot : 136
# Alberto Duport -- Karen Clarens : 54
# Alberto Duport -- Kim Passa : 45
# Alberto Duport -- Kiu Kan : 76
# Alberto Duport -- Magdalena Predutta : 137
# Alberto Duport -- Maris Freeman : 58
# Alberto Duport -- Miu Hanwan : 43
# Alberto Duport -- Nico Ojenbeer : 53
# Alberto Duport -- Pedro Alvares : 116
# Alberto Duport -- Penn Osterwalder : 44
# Alberto Duport -- Sean Manney : 54
# Alberto Duport -- Tesca Lobes : 45
# Anna Kaufmann -- Anne Olwada : 47
# Anna Kaufmann -- Carmen Finacse : 65
# Anna Kaufmann -- Christian Francois : 39
# Anna Kaufmann -- Clement Duchot : 37
# Anna Kaufmann -- Elvira Lores : 37
# Anna Kaufmann -- Esmana Liubiata : 41
# Anna Kaufmann -- Esmeralda Clay : 48
# Anna Kaufmann -- Fjodor Kowalski : 37
# Anna Kaufmann -- Francis Odell : 43
# Anna Kaufmann -- Francois de Perrier : 126
# Anna Kaufmann -- Heinz Gutschmidt : 38
# Anna Kaufmann -- Immanuel Karagianni : 45
# Anna Kaufmann -- Karalda Nimwada : 107
# Anna Kaufmann -- Karel de Groot : 128
# Anna Kaufmann -- Karen Clarens : 45
# Anna Kaufmann -- Kim Passa : 41
# Anna Kaufmann -- Kiu Kan : 77
# Anna Kaufmann -- Magdalena Predutta : 127
# Anna Kaufmann -- Maris Freeman : 42
# Anna Kaufmann -- Miu Hanwan : 38
# Anna Kaufmann -- Nico Ojenbeer : 45
# Anna Kaufmann -- Pedro Alvares : 105
# Anna Kaufmann -- Penn Osterwalder : 28
# Anna Kaufmann -- Sean Manney : 63
# Anna Kaufmann -- Tesca Lobes : 39
# Anne Olwada -- Carmen Finacse : 67
# Anne Olwada -- Christian Francois : 49
# Anne Olwada -- Clement Duchot : 45
# Anne Olwada -- Elvira Lores : 41
# Anne Olwada -- Esmana Liubiata : 43
# Anne Olwada -- Esmeralda Clay : 61
# Anne Olwada -- Fjodor Kowalski : 45
# Anne Olwada -- Francis Odell : 58
# Anne Olwada -- Francois de Perrier : 138
# Anne Olwada -- Heinz Gutschmidt : 48
# Anne Olwada -- Immanuel Karagianni : 52
# Anne Olwada -- Karalda Nimwada : 118
# Anne Olwada -- Karel de Groot : 141
# Anne Olwada -- Karen Clarens : 53
# Anne Olwada -- Kim Passa : 47
# Anne Olwada -- Kiu Kan : 83
# Anne Olwada -- Magdalena Predutta : 144
# Anne Olwada -- Maris Freeman : 52
# Anne Olwada -- Miu Hanwan : 52
# Anne Olwada -- Nico Ojenbeer : 49
# Anne Olwada -- Pedro Alvares : 122
# Anne Olwada -- Penn Osterwalder : 44
# Anne Olwada -- Sean Manney : 65
# Anne Olwada -- Tesca Lobes : 51
# Carmen Finacse -- Christian Francois : 71
# Carmen Finacse -- Clement Duchot : 65
# Carmen Finacse -- Elvira Lores : 62
# Carmen Finacse -- Esmana Liubiata : 66
# Carmen Finacse -- Esmeralda Clay : 76
# Carmen Finacse -- Fjodor Kowalski : 77
# Carmen Finacse -- Francis Odell : 63
# Carmen Finacse -- Francois de Perrier : 187
# Carmen Finacse -- Heinz Gutschmidt : 52
# Carmen Finacse -- Immanuel Karagianni : 67
# Carmen Finacse -- Karalda Nimwada : 174
# Carmen Finacse -- Karel de Groot : 183
# Carmen Finacse -- Karen Clarens : 64
# Carmen Finacse -- Kim Passa : 69
# Carmen Finacse -- Kiu Kan : 94
# Carmen Finacse -- Magdalena Predutta : 192
# Carmen Finacse -- Maris Freeman : 66
# Carmen Finacse -- Miu Hanwan : 71
# Carmen Finacse -- Nico Ojenbeer : 76
# Carmen Finacse -- Pedro Alvares : 183
# Carmen Finacse -- Penn Osterwalder : 58
# Carmen Finacse -- Sean Manney : 80
# Carmen Finacse -- Tesca Lobes : 69
# Christian Francois -- Clement Duchot : 50
# Christian Francois -- Elvira Lores : 47
# Christian Francois -- Esmana Liubiata : 41
# Christian Francois -- Esmeralda Clay : 57
# Christian Francois -- Fjodor Kowalski : 46
# Christian Francois -- Francis Odell : 50
# Christian Francois -- Francois de Perrier : 131
# Christian Francois -- Heinz Gutschmidt : 46
# Christian Francois -- Immanuel Karagianni : 52
# Christian Francois -- Karalda Nimwada : 114
# Christian Francois -- Karel de Groot : 131
# Christian Francois -- Karen Clarens : 51
# Christian Francois -- Kim Passa : 39
# Christian Francois -- Kiu Kan : 84
# Christian Francois -- Magdalena Predutta : 143
# Christian Francois -- Maris Freeman : 60
# Christian Francois -- Miu Hanwan : 52
# Christian Francois -- Nico Ojenbeer : 43
# Christian Francois -- Pedro Alvares : 121
# Christian Francois -- Penn Osterwalder : 30
# Christian Francois -- Sean Manney : 68
# Christian Francois -- Tesca Lobes : 42
# Clement Duchot -- Elvira Lores : 38
# Clement Duchot -- Esmana Liubiata : 37
# Clement Duchot -- Esmeralda Clay : 61
# Clement Duchot -- Fjodor Kowalski : 42
# Clement Duchot -- Francis Odell : 44
# Clement Duchot -- Francois de Perrier : 132
# Clement Duchot -- Heinz Gutschmidt : 49
# Clement Duchot -- Immanuel Karagianni : 48
# Clement Duchot -- Karalda Nimwada : 117
# Clement Duchot -- Karel de Groot : 132
# Clement Duchot -- Karen Clarens : 59
# Clement Duchot -- Kim Passa : 44
# Clement Duchot -- Kiu Kan : 81
# Clement Duchot -- Magdalena Predutta : 137
# Clement Duchot -- Maris Freeman : 46
# Clement Duchot -- Miu Hanwan : 53
# Clement Duchot -- Nico Ojenbeer : 47
# Clement Duchot -- Pedro Alvares : 118
# Clement Duchot -- Penn Osterwalder : 49
# Clement Duchot -- Sean Manney : 65
# Clement Duchot -- Tesca Lobes : 36
# Elvira Lores -- Esmana Liubiata : 42
# Elvira Lores -- Esmeralda Clay : 61
# Elvira Lores -- Fjodor Kowalski : 49
# Elvira Lores -- Francis Odell : 56
# Elvira Lores -- Francois de Perrier : 130
# Elvira Lores -- Heinz Gutschmidt : 51
# Elvira Lores -- Immanuel Karagianni : 47
# Elvira Lores -- Karalda Nimwada : 121
# Elvira Lores -- Karel de Groot : 135
# Elvira Lores -- Karen Clarens : 53
# Elvira Lores -- Kim Passa : 42
# Elvira Lores -- Kiu Kan : 77
# Elvira Lores -- Magdalena Predutta : 136
# Elvira Lores -- Maris Freeman : 51
# Elvira Lores -- Miu Hanwan : 50
# Elvira Lores -- Nico Ojenbeer : 45
# Elvira Lores -- Pedro Alvares : 124
# Elvira Lores -- Penn Osterwalder : 48
# Elvira Lores -- Sean Manney : 61
# Elvira Lores -- Tesca Lobes : 44
# Esmana Liubiata -- Esmeralda Clay : 62
# Esmana Liubiata -- Fjodor Kowalski : 44
# Esmana Liubiata -- Francis Odell : 51
# Esmana Liubiata -- Francois de Perrier : 134
# Esmana Liubiata -- Heinz Gutschmidt : 44
# Esmana Liubiata -- Immanuel Karagianni : 53
# Esmana Liubiata -- Karalda Nimwada : 115
# Esmana Liubiata -- Karel de Groot : 129
# Esmana Liubiata -- Karen Clarens : 55
# Esmana Liubiata -- Kim Passa : 45
# Esmana Liubiata -- Kiu Kan : 82
# Esmana Liubiata -- Magdalena Predutta : 129
# Esmana Liubiata -- Maris Freeman : 45
# Esmana Liubiata -- Miu Hanwan : 50
# Esmana Liubiata -- Nico Ojenbeer : 50
# Esmana Liubiata -- Pedro Alvares : 120
# Esmana Liubiata -- Penn Osterwalder : 48
# Esmana Liubiata -- Sean Manney : 54
# Esmana Liubiata -- Tesca Lobes : 41
# Esmeralda Clay -- Fjodor Kowalski : 64
# Esmeralda Clay -- Francis Odell : 66
# Esmeralda Clay -- Francois de Perrier : 175
# Esmeralda Clay -- Heinz Gutschmidt : 58
# Esmeralda Clay -- Immanuel Karagianni : 64
# Esmeralda Clay -- Karalda Nimwada : 160
# Esmeralda Clay -- Karel de Groot : 174
# Esmeralda Clay -- Karen Clarens : 69
# Esmeralda Clay -- Kim Passa : 65
# Esmeralda Clay -- Kiu Kan : 91
# Esmeralda Clay -- Magdalena Predutta : 175
# Esmeralda Clay -- Maris Freeman : 75
# Esmeralda Clay -- Miu Hanwan : 65
# Esmeralda Clay -- Nico Ojenbeer : 70
# Esmeralda Clay -- Pedro Alvares : 163
# Esmeralda Clay -- Penn Osterwalder : 63
# Esmeralda Clay -- Sean Manney : 70
# Esmeralda Clay -- Tesca Lobes : 73
# Fjodor Kowalski -- Francis Odell : 52
# Fjodor Kowalski -- Francois de Perrier : 134
# Fjodor Kowalski -- Heinz Gutschmidt : 46
# Fjodor Kowalski -- Immanuel Karagianni : 46
# Fjodor Kowalski -- Karalda Nimwada : 116
# Fjodor Kowalski -- Karel de Groot : 142
# Fjodor Kowalski -- Karen Clarens : 53
# Fjodor Kowalski -- Kim Passa : 51
# Fjodor Kowalski -- Kiu Kan : 78
# Fjodor Kowalski -- Magdalena Predutta : 143
# Fjodor Kowalski -- Maris Freeman : 60
# Fjodor Kowalski -- Miu Hanwan : 39
# Fjodor Kowalski -- Nico Ojenbeer : 50
# Fjodor Kowalski -- Pedro Alvares : 119
# Fjodor Kowalski -- Penn Osterwalder : 47
# Fjodor Kowalski -- Sean Manney : 62
# Fjodor Kowalski -- Tesca Lobes : 44
# Francis Odell -- Francois de Perrier : 155
# Francis Odell -- Heinz Gutschmidt : 79
# Francis Odell -- Immanuel Karagianni : 59
# Francis Odell -- Karalda Nimwada : 117
# Francis Odell -- Karel de Groot : 155
# Francis Odell -- Karen Clarens : 63
# Francis Odell -- Kim Passa : 47
# Francis Odell -- Kiu Kan : 83
# Francis Odell -- Magdalena Predutta : 160
# Francis Odell -- Maris Freeman : 85
# Francis Odell -- Miu Hanwan : 56
# Francis Odell -- Nico Ojenbeer : 55
# Francis Odell -- Pedro Alvares : 124
# Francis Odell -- Penn Osterwalder : 50
# Francis Odell -- Sean Manney : 70
# Francis Odell -- Tesca Lobes : 48
# Francois de Perrier -- Heinz Gutschmidt : 133
# Francois de Perrier -- Immanuel Karagianni : 145
# Francois de Perrier -- Karalda Nimwada : 321
# Francois de Perrier -- Karel de Groot : 364
# Francois de Perrier -- Karen Clarens : 158
# Francois de Perrier -- Kim Passa : 142
# Francois de Perrier -- Kiu Kan : 223
# Francois de Perrier -- Magdalena Predutta : 366
# Francois de Perrier -- Maris Freeman : 153
# Francois de Perrier -- Miu Hanwan : 137
# Francois de Perrier -- Nico Ojenbeer : 152
# Francois de Perrier -- Pedro Alvares : 329
# Francois de Perrier -- Penn Osterwalder : 137
# Francois de Perrier -- Sean Manney : 165
# Francois de Perrier -- Tesca Lobes : 138
# Heinz Gutschmidt -- Immanuel Karagianni : 43
# Heinz Gutschmidt -- Karalda Nimwada : 109
# Heinz Gutschmidt -- Karel de Groot : 138
# Heinz Gutschmidt -- Karen Clarens : 60
# Heinz Gutschmidt -- Kim Passa : 46
# Heinz Gutschmidt -- Kiu Kan : 75
# Heinz Gutschmidt -- Magdalena Predutta : 136
# Heinz Gutschmidt -- Maris Freeman : 62
# Heinz Gutschmidt -- Miu Hanwan : 49
# Heinz Gutschmidt -- Nico Ojenbeer : 53
# Heinz Gutschmidt -- Pedro Alvares : 109
# Heinz Gutschmidt -- Penn Osterwalder : 46
# Heinz Gutschmidt -- Sean Manney : 59
# Heinz Gutschmidt -- Tesca Lobes : 46
# Immanuel Karagianni -- Karalda Nimwada : 128
# Immanuel Karagianni -- Karel de Groot : 139
# Immanuel Karagianni -- Karen Clarens : 65
# Immanuel Karagianni -- Kim Passa : 56
# Immanuel Karagianni -- Kiu Kan : 92
# Immanuel Karagianni -- Magdalena Predutta : 151
# Immanuel Karagianni -- Maris Freeman : 56
# Immanuel Karagianni -- Miu Hanwan : 56
# Immanuel Karagianni -- Nico Ojenbeer : 50
# Immanuel Karagianni -- Pedro Alvares : 130
# Immanuel Karagianni -- Penn Osterwalder : 44
# Immanuel Karagianni -- Sean Manney : 70
# Immanuel Karagianni -- Tesca Lobes : 51
# Karalda Nimwada -- Karel de Groot : 324
# Karalda Nimwada -- Karen Clarens : 155
# Karalda Nimwada -- Kim Passa : 112
# Karalda Nimwada -- Kiu Kan : 208
# Karalda Nimwada -- Magdalena Predutta : 328
# Karalda Nimwada -- Maris Freeman : 125
# Karalda Nimwada -- Miu Hanwan : 120
# Karalda Nimwada -- Nico Ojenbeer : 123
# Karalda Nimwada -- Pedro Alvares : 299
# Karalda Nimwada -- Penn Osterwalder : 114
# Karalda Nimwada -- Sean Manney : 157
# Karalda Nimwada -- Tesca Lobes : 123
# Karel de Groot -- Karen Clarens : 161
# Karel de Groot -- Kim Passa : 145
# Karel de Groot -- Kiu Kan : 226
# Karel de Groot -- Magdalena Predutta : 374
# Karel de Groot -- Maris Freeman : 152
# Karel de Groot -- Miu Hanwan : 143
# Karel de Groot -- Nico Ojenbeer : 151
# Karel de Groot -- Pedro Alvares : 331
# Karel de Groot -- Penn Osterwalder : 130
# Karel de Groot -- Sean Manney : 169
# Karel de Groot -- Tesca Lobes : 138
# Karen Clarens -- Kim Passa : 65
# Karen Clarens -- Kiu Kan : 92
# Karen Clarens -- Magdalena Predutta : 165
# Karen Clarens -- Maris Freeman : 64
# Karen Clarens -- Miu Hanwan : 60
# Karen Clarens -- Nico Ojenbeer : 61
# Karen Clarens -- Pedro Alvares : 147
# Karen Clarens -- Penn Osterwalder : 60
# Karen Clarens -- Sean Manney : 44
# Karen Clarens -- Tesca Lobes : 63
# Kim Passa -- Kiu Kan : 82
# Kim Passa -- Magdalena Predutta : 140
# Kim Passa -- Maris Freeman : 50
# Kim Passa -- Miu Hanwan : 47
# Kim Passa -- Nico Ojenbeer : 50
# Kim Passa -- Pedro Alvares : 121
# Kim Passa -- Penn Osterwalder : 40
# Kim Passa -- Sean Manney : 59
# Kim Passa -- Tesca Lobes : 51
# Kiu Kan -- Magdalena Predutta : 230
# Kiu Kan -- Maris Freeman : 87
# Kiu Kan -- Miu Hanwan : 91
# Kiu Kan -- Nico Ojenbeer : 85
# Kiu Kan -- Pedro Alvares : 214
# Kiu Kan -- Penn Osterwalder : 79
# Kiu Kan -- Sean Manney : 96
# Kiu Kan -- Tesca Lobes : 75
# Magdalena Predutta -- Maris Freeman : 158
# Magdalena Predutta -- Miu Hanwan : 143
# Magdalena Predutta -- Nico Ojenbeer : 151
# Magdalena Predutta -- Pedro Alvares : 338
# Magdalena Predutta -- Penn Osterwalder : 132
# Magdalena Predutta -- Sean Manney : 170
# Magdalena Predutta -- Tesca Lobes : 142
# Maris Freeman -- Miu Hanwan : 56
# Maris Freeman -- Nico Ojenbeer : 54
# Maris Freeman -- Pedro Alvares : 124
# Maris Freeman -- Penn Osterwalder : 57
# Maris Freeman -- Sean Manney : 59
# Maris Freeman -- Tesca Lobes : 52
# Miu Hanwan -- Nico Ojenbeer : 55
# Miu Hanwan -- Pedro Alvares : 119
# Miu Hanwan -- Penn Osterwalder : 40
# Miu Hanwan -- Sean Manney : 57
# Miu Hanwan -- Tesca Lobes : 46
# Nico Ojenbeer -- Pedro Alvares : 125
# Nico Ojenbeer -- Penn Osterwalder : 49
# Nico Ojenbeer -- Sean Manney : 62
# Nico Ojenbeer -- Tesca Lobes : 47
# Pedro Alvares -- Penn Osterwalder : 124
# Pedro Alvares -- Sean Manney : 165
# Pedro Alvares -- Tesca Lobes : 127
# Penn Osterwalder -- Sean Manney : 65
# Penn Osterwalder -- Tesca Lobes : 43
# Sean Manney -- Tesca Lobes : 63

# %%
# Listing 24 Generating an undirected graph with PyGraphviz
import graphviz as gv

G = gv.Graph(strict=False)

G.graph_attr['rankdir'] = 'LR'
G.node_attr['shape'] = 'circle'

for ui in W:
    for uj in W[ui]:
        G.edge(ui, uj, label=str(W[ui][uj]))

G

# %%
# Listing 24 Generating an undirected graph with PyGraphviz
import graphviz as gv

G = gv.Graph(strict=False)

G.graph_attr['rankdir'] = 'LR'
G.node_attr['shape'] = 'circle'

values = [W[ui][uj] for ui in W for uj in W[ui]]
x_min = min(values)
x_max = max(values)

y_min = 1.0
y_max = 5.0

for ui in W:
    for uj in W[ui]:
        x = W[ui][uj]
        y = y_min + (y_max-y_min) * (float(x-x_min) / float(x_max-x_min))**3
        G.edge(ui, uj, label=str(x), penwidth=str(y))

G

# %% [markdown]
# > *Users and activites* measures

# %%
# Listing 26 Collecting the set of activities performed by each user
import graphviz as gv

UA = dict()
for caseid in log:
    for i in range(0, len(log[caseid])):
        ai = log[caseid][i][0]
        ui = log[caseid][i][1]
        if ui not in UA:
            UA[ui] = set()
        UA[ui].add(ai)

G = gv.Graph(strict=False)

G.graph_attr['rankdir'] = 'LR'
G.node_attr['shape'] = 'circle'

U = sorted(UA.keys())
for i in range(0, len(U)-1):
    for j in range(i+1, len(U)):
        ui = U[i]
        uj = U[j]
        x = len(UA[ui] & UA[uj])
        if x > 0:
            G.edge(ui, uj, label=str(x))

G

# %%
# Listing 28 Counting the number of times that each user performed each task

import graphviz as gv

UA = dict()

for caseid in log:
    for i in range(0, len(log[caseid])):
        ai = log[caseid][i][0]
        ui = log[caseid][i][1]
        if ui not in UA:
            UA[ui] = dict()
        if ai not in UA[ui]:
            UA[ui][ai] = 0
        UA[ui][ai] += 1

G = gv.Graph(strict=False)

G.graph_attr['rankdir'] = 'LR'
G.node_attr['shape'] = 'circle'

values = [UA[ui][ai] for ui in UA for ai in UA[ui]]
x_min = min(values)
x_max = max(values)

y_min = 1.0
y_max = 5.0

for ui in UA:
    for ai in UA[ui]:
        x = UA[ui][ai]
        y = y_min + (y_max-y_min) * float(x-x_min) / float(x_max-x_min)
        G.edge(ui, ai, label=str(x), penwidth=str(y))

G

# %% [markdown]
# Performance perspective
# =======================

# %% [markdown]
# Consider to change legend localization by: "loc='upper center', bbox_to_anchor=(0.5, -0.05)"

# %%
# Listing 35 Plotting a dotted chart with Matplotlib

import matplotlib.pyplot as plt

X = dict()
Y = dict()

caseids = sorted(log.keys(),key=lambda caseid: log[caseid][0][-1])

for (y, caseid) in enumerate(caseids):
    for i in range(0, len(log[caseid])):
        (a, _, x) = log[caseid][i]
        if a not in X:
            X[a] = []
            Y[a] = []
        X[a].append(x)
        Y[a].append(y)

for a in sorted(X.keys()):
    plt.plot(X[a], Y[a], 'o', label=a, markersize=20, markeredgewidth=0., alpha=0.5)

axes = plt.gca()

axes.set_yticks(range(len(caseids)))
axes.set_ylim(-1, len(caseids))
axes.set_yticklabels(caseids)
axes.set_ylabel('case id')
axes.invert_yaxis()

axes.set_xlabel('timestamp')
axes.xaxis.tick_top()
axes.xaxis.set_label_position('top')

plt.grid(True)
plt.legend(numpoints=1)
plt.tight_layout()
plt.show()

# %%
# Listing 36 Plotting a dotted chart with relative time

import matplotlib.pyplot as plt

X = dict()
Y = dict()

caseids = sorted(log.keys(),key=lambda caseid: log[caseid][-1][-1]-log[caseid][0][-1])

for (y, caseid) in enumerate(caseids):
    x0 = log[caseid][0][-1]
    for i in range(0, len(log[caseid])):
        (a, _, x) = log[caseid][i]
        if a not in X:
            X[a] = []
            Y[a] = []
        X[a].append((x-x0).total_seconds()/(24*3600))
        Y[a].append(y)

for a in sorted(X.keys()): 
    plt.plot(X[a], Y[a], 'o', label=a, markersize=20, markeredgewidth=0., alpha=0.5)

axes = plt.gca()

axes.set_yticks(range(len(caseids)))
axes.set_ylim(-1, len(caseids))
axes.set_yticklabels(caseids)
axes.set_ylabel('case id')
axes.invert_yaxis()

axes.set_xlabel('days') 
axes.xaxis.tick_top() 
axes.xaxis.set_label_position('top')

plt.grid(True)
plt.legend(numpoints=1)
plt.tight_layout()
plt.show()

# %%
# Listing 37 Plotting the histograms of activity execution time

import numpy as np
import matplotlib.pyplot as plt

D = dict()

for caseid in log:
    for i in range(0, len(log[caseid])):
        (a, _, t) = log[caseid][i] 
        if i > 0:
            (_, _, t0) = log[caseid][i-1]
            d = (t-t0).total_seconds()/(24*3600)
        else:
            d = 0. 
        if a not in D:
            D[a] = []
        D[a].append(d)

i = 0
for a in sorted(D.keys()):
    print sorted(D.keys())[i]
    i += 1
    plt.hist(D[a], bins=[0.1*k for k in range(100)])
    plt.show()
# Out:
# Amend Purchase Requisition
# Amend Request for Quotation Requester
# Amend Request for Quotation Requester Manager
# Analyze Purchase Requisition
# Analyze Quotation comparison Map
# Analyze Request for Quotation
# Approve Purchase Order for payment
# Authorize Supplier's Invoice payment
# Choose best option
# Confirm Purchase Order
# Create Purchase Order
# Create Purchase Requisition
# Create Quotation comparison Map
# Create Request for Quotation Requester
# Create Request for Quotation Requester Manager
# Deliver Goods Services
# Pay invoice
# Release Purchase Order
# Release Supplier's Invoice
# Send Request for Quotation to Supplier
# Send invoice
# Settle conditions with supplier
# Settle dispute with supplier Financial Manager
# Settle dispute with supplier Purchasing Agent
